# %%
import yaml

RNG = {
    'Hight': 7.68e-6,
    'Width': 7.15e-6,
    'EnergyPerSample': 16.3e-15,
    'Throughtput': 1e9,
    'EntropySource': 0.5,
    'SamplingMode': 'parallel',

}

with open('../../RNG.yaml', 'w') as file:
    yaml.dump(RNG, file, default_flow_style=False)

# %%
with open('../../RNG.yaml', 'r') as file:
    loaded_config = yaml.safe_load(file)


print(loaded_config)
# Out:
# {'EnergyPerSample': 1.63e-14, 'EntropySource': 0.5, 'Hight': 7.68e-06, 'SamplingMode': 'parallel', 'Throughtput': 1000000000.0, 'Width': 7.15e-06}
