# %%
import yaml

parm = {
    'operationmode': 'conventionalSequential',
    'deviceroadmap': 'HP',
    'transistortype': 'conventional',
    'readVoltage': 0.51,
}

with open('../../parm.yaml', 'w') as file:
    yaml.dump(parm, file, default_flow_style=False)

# %%
with open('../../parm.yaml', 'r') as file:
    loaded_config = yaml.safe_load(file)


print(loaded_config)
# Out:
# {'deviceroadmap': 'HP', 'operationmode': 'conventionalSequential', 'readVoltage': 0.51, 'transistortype': 'conventional'}
