# %%
import numpy as np
import math
import sys
sys.path.append('../../python/')  
from periphery import logicGate
from periphery import constant
print(constant.INV)

# %%
class SubArray:
    def __init__(self, tech, param, config,relaxArrayCellWidth,relaxArrayCellHeight):
        self.tech = tech
        self.param = param  ##technology parameters
        self.config = config ##user input parameters
        self.initialized = False
        self.relaxArrayCellWidth = relaxArrayCellWidth
        self.relaxArrayCellHeight = relaxArrayCellHeight
        self.sram_mode = False

    def initialize(self, numRow, numCol, unitWireRes):
        self.numRow = numRow
        self.numCol = numCol
        self.unitWireRes = unitWireRes

        self.feature_size = self.tech['featureSize']
        min_cell_height = self.tech['MAX_TRANSISTOR_HEIGHT'];  #set real layout cell height
        min_cell_width =  (self.tech['MIN_GAP_BET_GATE_POLY'] + self.tech['POLY_WIDTH']) * 2;  #set real layout cell width
        siolation_region = self.tech['MIN_POLY_EXT_DIFF'] * 2 + self.tech['MIN_GAP_BET_FIELD_POLY']

        #############################################
        # to be done: for the technology below 14nm, there will be some tuning for the cell width and height and islation region
        #############################################

        if self.cell.memCellType == 'SRAM':
            if self.relaxArrayCellWidth:
                width = max(self.config.widthInFeatureSize, min_cell_width)
                height = max(self.config.heightInFeatureSize, min_cell_height)
                self.lengthRow = numCol * width * self.feature_size
                self.lengthCol = numRow * height * self.feature_size
            else:
                self.lengthRow = numCol * self.config.widthInFeatureSize * self.feature_size
            if self.relaxArrayCellHeight:
                self.lengthCol = numRow * height * self.feature_size
            else:
                self.lengthCol = numRow * self.config.heightInFeatureSize * self.feature_size

        self.arraywidthunit = self.config.widthInFeatureSize * self.feature_size
        self.arrayheightunit = numRow * self.config.heightInFeatureSize * self.feature_size
        ###finish setting array size

        # elif self.cell.memCellType in ['RRAM', 'FeFET']:
        #     width = self.cell.widthInFeatureSize
        #     height = self.cell.heightInFeatureSize

        #     if self.cell.accessType == 'CMOS_access':
        #         width = max(width, min_cell_width * 2)
        #         height = max(height, min_cell_height)
        #     else:
        #         width = max(width * self.feature_size, min_cell_width * 2 * self.feature_size)
        #         height = max(height * self.feature_size, min_cell_height * self.feature_size)

        #     self.lengthRow = numCol * width
        #     self.lengthCol = numRow * height

        # cap and resistance calculation
        self.capRow1 = self.lengthRow * 0.2e-15 / 1e-6      # BL for 1T1R, WL for Cross-point and SRAM
        self.capRow2 = self.capRow1                         # WL for 1T1R
        self.capCol = self.lengthCol * 0.2e-15 / 1e-6
        self.resRow = self.lengthRow * self.config.Metal1_unitwireresis
        self.resCol = self.lengthCol * self.config.Metal0_unitwireresis

        #start to initialize the subarray modules
        if self.cell.memCellType == 'SRAM':
            #firstly calculate the CMOS resistance and capacitance
            width_access_cmos = self.config.widthAccessCMOS
            scale_factor = 2 if self.feature_size <= 14e-9 else 1
            effective_width = width_access_cmos * scale_factor * self.feature_size

            width_sram_cell_nmos = self.config.widthSRAMCellNMOS
            width_sram_cell_pmos = self.config.widthSRAMCellPMOS
            effective_width_nmos = width_sram_cell_nmos * scale_factor * self.feature_size
            effective_width_pmos = width_sram_cell_pmos * scale_factor * self.feature_size

            # resCellAccess = logic_gate.calculate_on_resistance(cell.widthAccessCMOS * ((tech.featureSize <= 14*1e-9)? 2:1) * tech.featureSize, NMOS, inputParameter.temperature, tech);
            resCellAccess = logic_gate.calculate_on_resistance(effective_width,constant.NMOS,self.config.temperature, self.tech)
            capCellAccess = logic_gate.calculate_drain_cap(effective_width,constant.NMOS, self.tech['MAX_TRANSISTOR_HEIGHT'] * self.feature_size, self.tech)
             
            cell.capSRAMCell = (capCellAccess + logic_gate.calculate_drain_cap(effective_width_nmos, constant.NMOS, self.tech['MAX_TRANSISTOR_HEIGHT'] * self.feature_size, self.tech) 
                        + logic_gate.calculate_drain_cap(effective_width_pmos, constant.PMOS, self.tech['MAX_TRANSISTOR_HEIGHT'] * self.feature_size, self.tech) 
                        + logic_gate.calculate_mos_gate_cap(effective_width_nmos, self.tech) + logic_gate.calculate_mos_gate_cap(effective_width_pmos, self.tech))
            
            unit_cap = self.capRow1/self.param['numColSubArray']
            unit_res = self.resRow/self.param['numColSubArray']
            if self.tech['featureSize'] <= 14e-9:
                # self.capCol += self.tech['cap_draintotal'] * self.cell.widthAccessCMOS * self.tech['effective_width'] * self.numRow
                print("to be done")
            else:
                drain_cap = logic_gate.calculate_drain_cap(effective_width, constant.NMOS, self.tech['MAX_TRANSISTOR_HEIGHT'] * self.tech['featureSize'], self.tech)
                self.capCol += drain_cap * self.numRow

            ##########################################################################
            #initialize the periphery
            ##########################################################################
            self.sram_write_driver = SRAMWriteDriver(self.input_param, self.tech, self.cell)
            self.precharger = Precharger(self.input_param, self.tech, self.cell)
            self.row_decoder = RowDecoder(mode="REGULAR_ROW",num_addr_row=int(math.ceil(math.log2(self.numRow))),mux=False,parallel=False,tech=self.tech,input_param=self.input_param)

            if self.sram_mode == "conventional_sequential":
                #sum up all the gate cap of access CMOS, as the row cap
                gate_cap = logic_gate.calculate_gate_cap(effective_width, self.tech)    
                #to be determined why the factor is 2
                ##################################################################################
                self.capRow1 += 2 * gate_cap * numCol  # 2 for NMOS and PMOS   
                #######initialize the write driver########################
                self.sram_write_driver.initialize(
                    num_col=self.numCol,
                    activity_col_write=self.activityColWrite,
                    num_write_cell_per_op=self.numWriteCellPerOperationNeuro
                )     
                #######initialize the wl decoder########################
                #######initialize the sense amp########################

                self.initialized = True

    def calculate__area(self):
        if not self.initialized:
            raise Exception("SubArray not initialized. Please call initialize() method first.")
        else:
            area = 0
            used_area = 0
            if self.cell.memCellType == 'SRAM':
                #array only
                height_array = self.lengthCol
                width_array = self.lengthRow
                area_array = height_array * width_array
                #precharger and writeDriver are always needed for all different designs
                precharger_area = precharger.calculate_area(NULL, widthArray, NONE)
                sram_write_driver_area = sramWriteDriver.calculate_area(NULL, widthArray, NONE)
                if self.sram_mode == "conventional_sequential":
                    WL_decoder_area = self.row_decoder.calculate_area(self.numRow, self.numCol)
                    ADC_area = self.sense_amp.calculate_area(self.numRow, self.numCol)
                    height = precharger_height + write_driver_height + height_array
                    width = WL_decoder_width + width_array
                    area = height * width
                    used_area = (area_array + precharger_area + sram_write_driver_area +
                               WL_decoder_area + ADC_area)
                    empty_area = area - used_area
    
    def calculate_latency(self, column_res, calculate_clk_freq):
        if not self.initialized:
            raise Exception("SubArray not initialized. Please call initialize() method first.")
        else:
            read_latency = 0
            read_latency_adc = 0
            read_latency_other = 0
            write_latency = 0

            if self.cell.memCellType == 'SRAM':
                if self.sram_mode == "conventional_sequential":
                    #calculate the read latency
                    num_read_op_per_row = self.numCol/num_read_cell_per_op
                    num_write_op_per_row = self.numCol * activity_col_write / num_write_cell_per_op
                    if (calculate_clk_freq):
                        wl_decoder_latency = self.row_decoder.calculate_latency(ramp_input=1e20,cap_row1,num_read=1,num_write=1)
                        precharger_latency = self.precharger.calculate_latency(cap_load=5e-15,num_read=1,num_write=1)

                        #read
                        scale_factor = 2 if self.feature_size <= 14e-9 else 1
                        res_pull_down = logic_gate.calculate_on_resistance(
                            self.config.width_sram_cell_nmos * self.feature_size * scale_factor, constant.NMOS, self.config.temperature, self.tech)
                        BL_cap_per_cell = self.capCol / self.numRow + cap_cell_access
                        BL_res_per_cell = self.resCol / self.numRow
                        Elmore_BL = (res_cell_access + res_pull_down) * BL_cap_per_cell * self.numRow + (BL_cap_per_cell * self.numRow * (self.numRow + 1)/2)
                        col_delay = Elmore_BL *
