# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# 数据文件目录
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]

pure_sram_data_folder = "./Data/simulation/pure_sram/mux8/area"
pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]

digital_sram_data_folder = "./Data/simulation/digital_sram/mux8/area"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]



# 临时存储所有数据
data_list_ps = []
data_list_pure_sram = []
data_list_digital_sram = []

# 读取所有 JSON 文件
for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    density = data["memory_density (bits/um^2)"]

    data_list_ps.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "density": density
    })
for file in pure_sram_files:
    filepath = os.path.join(pure_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    density = data["memory_density (bits/um^2)"]

    data_list_pure_sram.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "density": density
    })
for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    density = data["memory_density (bits/um^2)"]

    data_list_digital_sram.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "density": density
    })
    

# ✅ 按面积从小到大排序
data_list_ps.sort(key=lambda d: d["area"])
data_list_pure_sram.sort(key=lambda d: d["area"])
data_list_digital_sram.sort(key=lambda d: d["area"])

# 分离数据用于绘图
memory_sizes = [d["label"] for d in data_list_ps]
memory_density_sram_ps = [d["density"] for d in data_list_ps]

memory_density_sram_pure = [d["density"] for d in data_list_pure_sram]

memory_density_sram_digital = [d["density"] for d in data_list_digital_sram]
# 绘图
x = np.arange(len(memory_sizes))
bar_width = 0.4

plt.figure(figsize=(10, 6))
plt.bar(x - bar_width/3, memory_density_sram_digital, width=bar_width/3, label="Digital SRAM", color="skyblue")
plt.bar(x, memory_density_sram_ps, width=bar_width/3, label="ps-SRAM", color="lightgreen")
plt.bar(x + bar_width/3, memory_density_sram_pure, width=bar_width/3, label="Pure SRAM", color="salmon")


# 坐标轴与标题
plt.xticks(x, memory_sizes)
plt.xlabel("Memory Array Size (Rows × Cols)")
plt.ylabel("Memory Density (bit/mm²)")
plt.title("Memory Density vs Memory Size (Sorted by Array Area)")
plt.legend()
plt.grid(True, axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 14
#      11 pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]
#      13 digital_sram_data_folder = "./Data/simulation/digital_sram/mux8/area"
# ---> 14 digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]
#      18 # 临时存储所有数据
#      19 data_list_ps = []
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/simulation/digital_sram/mux8/area'

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 数据部分保持不变 =====================
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]

pure_sram_data_folder = "./Data/simulation/pure_sram/mux8/area"
pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]

digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]

data_list_ps, data_list_pure_sram, data_list_digital_sram = [], [], []

# 读取 JSON 文件（相同逻辑）
for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_memory_Density (bits/um^2)"]
    })

for file in pure_sram_files:
    filepath = os.path.join(pure_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_pure_sram.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_Memory_Density (bits/um^2)"]
    })

for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_digital_sram.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_memory_density (bits/um^2)"]
    })

# ✅ 排序
data_list_ps.sort(key=lambda d: d["area"])
data_list_pure_sram.sort(key=lambda d: d["area"])
data_list_digital_sram.sort(key=lambda d: d["area"])

# 提取绘图数据
memory_sizes = [d["label"] for d in data_list_ps]
memory_density_sram_ps = [d["density"] for d in data_list_ps]
memory_density_sram_pure = [d["density"] for d in data_list_pure_sram]
memory_density_sram_digital = [d["density"] for d in data_list_digital_sram]

# ===================== 绘图部分 =====================
x = np.arange(len(memory_sizes))
bar_width = 0.25

plt.figure(figsize=(11, 6))

# 更高级的颜色搭配
colors = {
    "digital": "#2C7BB6",  # 蓝
    "ps": "#66C2A5",       # 绿
    "pure": "#FC8D62"      # 红
}

bars1 = plt.bar(x - bar_width, memory_density_sram_digital, width=bar_width, label="Digital SRAM", edgecolor='black', color=colors["digital"], alpha=0.9)
bars2 = plt.bar(x, memory_density_sram_ps, width=bar_width, label="ps-SRAM", edgecolor='black', color=colors["ps"], alpha=0.9)
bars3 = plt.bar(x + bar_width, memory_density_sram_pure, width=bar_width, label="Pure SRAM", edgecolor='black', color=colors["pure"], alpha=0.9)

# # 数值标注
# for bars in [bars1, bars2, bars3]:
#     for bar in bars:
#         yval = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005*yval, f'{yval:.3f}', 
#                  ha='center', va='bottom', fontsize=9, rotation=0)

# 坐标轴与样式优化
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=10)
plt.ylabel("Memory Density (bits/μm²)", fontsize=12, labelpad=10)
plt.title("Used Memory Density vs Memory Size (4bitADC-12CLT-mux16)", fontsize=14, fontweight='bold', pad=15)

# 网格与边界
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tick_params(axis='both', which='major', labelsize=10)
plt.legend(frameon=True, fontsize=11)
plt.tight_layout()

# 背景略微提亮
plt.gca().set_facecolor("#F9F9F9")
plt.savefig("./figure/memory_density_comparison_4bitADC_12CLT_mux8.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 文件路径 =====================
ps_sram_area_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
ps_sram_files = [f for f in os.listdir(ps_sram_area_folder) if f.endswith(".json")]

# ===================== 提取每个 Memory Size 的 Breakdown =====================
area_breakdowns = {}
module_set = set()

for file in ps_sram_files:
    filepath = os.path.join(ps_sram_area_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    
    label = f"{data['num_rows']}x{data['num_cols']}"
    exclude_keys = [
        "num_rows", "num_cols", "num_muxed_cols", "adc_precision", "MUX_Block",
        "MUX_Bus", "MUX", "MUX_Decoder","WL_Decoder","Pre_Charge","SRAM_Write_Driver",
        "Total Area", "Used_area",
        "Memory_Density (bits/um^2)", "Used_memory_Density (bits/um^2)"
    ]
    breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
    total_area = sum(breakdown.values())
    breakdown = {k: v / total_area for k, v in breakdown.items()}  # 转为比例

    area_breakdowns[label] = breakdown
    module_set.update(breakdown.keys())

# ===================== 统一模块顺序 =====================
modules = list(module_set)

# ===================== Memory Density 数据 =====================
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]
data_list_ps = []

for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_memory_Density (bits/um^2)"]
    })

data_list_ps.sort(key=lambda d: d["area"])
memory_sizes = [d["label"] for d in data_list_ps]
memory_density = [d["density"] for d in data_list_ps]

# ===================== 绘制堆叠柱状图 =====================
plt.figure(figsize=(11, 6), dpi=120)
x = np.arange(len(memory_sizes))
bar_width = 0.6

# 模块配色与 pattern
colors = plt.cm.tab20c(np.linspace(0, 1, len(modules)))
hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']

bottom = np.zeros(len(memory_sizes))
for i, module in enumerate(modules):
    values = []
    for size in memory_sizes:
        if module in area_breakdowns[size]:
            values.append(area_breakdowns[size][module] * memory_density[memory_sizes.index(size)])
        else:
            values.append(0)
    
    plt.bar(
        x, values, bar_width,
        bottom=bottom,
        label=module,
        color=colors[i % len(colors)],
        edgecolor='black',
        hatch=hatches[i % len(hatches)],
        alpha=0.9
    )
    bottom += np.array(values)

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=10)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=10)
plt.title("Probabilistic SRAM Area-Composition Weighted Memory Density\n(4bitADC, MUX8)", fontsize=14, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=9, frameon=True, ncol=2)
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# # 保存
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_memory_density_with_area_pattern.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 文件路径 =====================
pure_sram_data_folder = "./Data/simulation/pure_sram/mux8/area"
pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]

# ===================== 提取每个 Memory Size 的 Breakdown =====================
area_breakdowns = {}
module_set = set()

for file in pure_sram_files:
    filepath = os.path.join(pure_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    
    label = f"{data['num_rows']}x{data['num_cols']}"
    exclude_keys = [
    "num_rows", "num_cols", "num_col_muxed",
    "MUX_Bus", "MUX", "MUX_Decoder", "WL_Decoder","Pre_charge","SRAM_Write_Driver","MUX_Block",
    "Total Area", "Used Area",
    "Memory_Density (bits/um^2)", "Used_Memory_Density (bits/um^2)"
]
    breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
    total_area = sum(breakdown.values())
    breakdown = {k: v / total_area for k, v in breakdown.items()}  # 转为比例

    area_breakdowns[label] = breakdown
    module_set.update(breakdown.keys())

# ===================== 统一模块顺序 =====================
modules = list(module_set)

# ===================== Memory Density 数据 =====================
pure_sram_data_folder = "./Data/simulation/pure_sram/mux8/area"
pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]
data_list_ps = []

for file in pure_sram_files:
    filepath = os.path.join(pure_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_Memory_Density (bits/um^2)"]
    })

data_list_ps.sort(key=lambda d: d["area"])
memory_sizes = [d["label"] for d in data_list_ps]
memory_density = [d["density"] for d in data_list_ps]

# ===================== 绘制堆叠柱状图 =====================
plt.figure(figsize=(11, 6), dpi=120)
x = np.arange(len(memory_sizes))
bar_width = 0.6

# 模块配色与 pattern
colors = plt.cm.tab20c(np.linspace(0, 1, len(modules)))
hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']

bottom = np.zeros(len(memory_sizes))
for i, module in enumerate(modules):
    values = []
    for size in memory_sizes:
        if module in area_breakdowns[size]:
            values.append(area_breakdowns[size][module] * memory_density[memory_sizes.index(size)])
        else:
            values.append(0)
    
    plt.bar(
        x, values, bar_width,
        bottom=bottom,
        label=module,
        color=colors[i % len(colors)],
        edgecolor='black',
        hatch=hatches[i % len(hatches)],
        alpha=0.9
    )
    bottom += np.array(values)

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=10)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=10)
plt.title("SRAM Area-Composition Weighted Memory Density\n(4bitADC, MUX8)", fontsize=14, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=9, frameon=True, ncol=2)
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# # 保存
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_memory_density_with_area_pattern.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 文件路径 =====================
digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]

# ===================== 提取每个 Memory Size 的 Breakdown =====================
area_breakdowns = {}
module_set = set()

for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    
    label = f"{data['num_rows']}x{data['num_cols']}"
    exclude_keys = [
    "num_rows", "num_cols", "num_col_muxed","clt_num",
    "MUX_Bus", "MUX", "MUX_Decoder", "WL_Decoder","Pre_Charge","SRAM_Write_Driver","MUX_BLOCK",
    "Total Area", "Used Area",
    "Memory_Density (bits/um^2)", "Used_memory_density (bits/um^2)"
]
    breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
    total_area = sum(breakdown.values())
    breakdown = {k: v / total_area for k, v in breakdown.items()}  # 转为比例

    area_breakdowns[label] = breakdown
    module_set.update(breakdown.keys())

# ===================== 统一模块顺序 =====================
modules = list(module_set)

# ===================== Memory Density 数据 =====================
digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]
data_list_ps = []

for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "area": data["num_rows"] * data["num_cols"],
        "density": data["Used_memory_density (bits/um^2)"]
    })

data_list_ps.sort(key=lambda d: d["area"])
memory_sizes = [d["label"] for d in data_list_ps]
memory_density = [d["density"] for d in data_list_ps]

# ===================== 绘制堆叠柱状图 =====================
plt.figure(figsize=(11, 6), dpi=120)
x = np.arange(len(memory_sizes))
bar_width = 0.6

# 模块配色与 pattern
colors = plt.cm.tab20c(np.linspace(0, 1, len(modules)))
hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']

bottom = np.zeros(len(memory_sizes))
for i, module in enumerate(modules):
    values = []
    for size in memory_sizes:
        if module in area_breakdowns[size]:
            values.append(area_breakdowns[size][module] * memory_density[memory_sizes.index(size)])
        else:
            values.append(0)
    
    plt.bar(
        x, values, bar_width,
        bottom=bottom,
        label=module,
        color=colors[i % len(colors)],
        edgecolor='black',
        hatch=hatches[i % len(hatches)],
        alpha=0.9
    )
    bottom += np.array(values)

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=10)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=10)
plt.title("SRAM Area-Composition Weighted Memory Density\n(4bitADC, MUX8)", fontsize=14, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=9, frameon=True, ncol=2)
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# # 保存
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_memory_density_with_area_pattern.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

# ===================== 基础设置 =====================
plt.rcParams['hatch.linewidth'] = 0.9  # hatch 粗细略粗一点，更清晰
plt.rcParams['axes.linewidth'] = 1.2   # 坐标轴更清晰
plt.rcParams['font.family'] = 'DejaVu Sans'  # 字体兼容性好
plt.rcParams['figure.dpi'] = 150

# ===================== 通用函数：读取 Breakdown =====================
def load_breakdown(folder, key_density_name):
    files = [f for f in os.listdir(folder) if f.endswith(".json")]
    data_list, breakdowns, modules = [], {}, set()

    for file in files:
        with open(os.path.join(folder, file), "r") as f:
            data = json.load(f)
        label = f"{data['num_rows']}x{data['num_cols']}"
        exclude_keys = [
            "num_rows", "num_cols", "num_muxed_cols", "num_col_muxed", "adc_precision", "clt_num",
            "MUX_Block","MUX_BLOCK","MUX_Bus","MUX","MUX_Decoder",
            "WL_Decoder","Pre_Charge","Pre_charge","SRAM_Write_Driver",
            "Total Area","Used_area","Used Area",
            "Memory_Density (bits/um^2)","Used_memory_Density (bits/um^2)",
            "Used_Memory_Density (bits/um^2)","Used_memory_density (bits/um^2)"
        ]
        breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
        total_area = sum(breakdown.values())
        breakdown = {k: v / total_area for k, v in breakdown.items()}  # 模块占比
        breakdowns[label] = breakdown
        modules.update(breakdown.keys())

        data_list.append({
            "label": label,
            "area": data["num_rows"] * data["num_cols"],
            "density": data[key_density_name]
        })
    data_list.sort(key=lambda d: d["area"])
    return data_list, breakdowns, list(modules)


# ===================== 三类 SRAM 文件路径 =====================
ps_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
digital_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
pure_folder = "./Data/simulation/pure_sram/mux8/area"

# ===================== 读取数据 =====================
ps_data, ps_break, ps_mod = load_breakdown(ps_folder, "Used_memory_Density (bits/um^2)")
digital_data, digital_break, dig_mod = load_breakdown(digital_folder, "Used_memory_density (bits/um^2)")
pure_data, pure_break, pure_mod = load_breakdown(pure_folder, "Used_Memory_Density (bits/um^2)")

modules = sorted(set(ps_mod + dig_mod + pure_mod))  # 统一模块顺序

# ===================== 对齐 Memory Size =====================
memory_sizes = [d["label"] for d in ps_data]
ps_density = [d["density"] for d in ps_data]
digital_density = [d["density"] for d in digital_data]
pure_density = [d["density"] for d in pure_data]

# ===================== 主色与 Pattern =====================
colors = {
    "digital": "#2C7BB6",  # 蓝
    "ps": "#66C2A5",       # 绿
    "pure": "#FC8D62"      # 红
}
hatches = [
    '////',   # 右上斜线
    '\\\\\\\\', # 左上斜线
    '||',     # 垂直条纹
    '--',     # 水平条纹
    'xx',     # 交叉斜线
    '++',     # 十字交叉
    '..',     # 密点
    'oo',     # 圆点
    '**',     # 星点
    'OO'      # 大圆
]

# ===================== 绘图 =====================
plt.figure(figsize=(10, 5.8))  # 更紧凑，论文比例更佳
x = np.arange(len(memory_sizes))
bar_width = 0.23

def plot_stacked(breakdowns, densities, offset, label, base_color):
    bottom = np.zeros(len(memory_sizes))
    for i, module in enumerate(modules):
        vals = []
        for size in memory_sizes:
            frac = breakdowns.get(size, {}).get(module, 0)
            idx = memory_sizes.index(size)
            vals.append(frac * densities[idx])
        plt.bar(
            x + offset, vals, bar_width,
            bottom=bottom,
            color=base_color,
            edgecolor='black',
            hatch=hatches[i % len(hatches)],
            linewidth=0.8,
            alpha=0.9
        )
        bottom += np.array(vals)
    # 类型 legend
    plt.bar(0, 0, color=base_color, edgecolor='black', label=label,alpha=0.9)


# 绘制三类 SRAM（蓝、绿、红）
plot_stacked(digital_break, digital_density, -bar_width, "Digital SRAM", colors["digital"],)
plot_stacked(ps_break, ps_density, 0, "ps-SRAM", colors["ps"])
plot_stacked(pure_break, pure_density, bar_width, "Pure SRAM", colors["pure"])

# ===================== 模块线条图例 =====================
module_handles = [
    Patch(facecolor='white', edgecolor='black', hatch=hatches[i % len(hatches)], label=modules[i])
    for i in range(len(modules))
]

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=8)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=8)
plt.title("Area-Composition Weighted Memory Density Breakdown\n(Digital, ps-, and Pure SRAM, MUX8)",
          fontsize=13, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.6, linewidth=0.7)
plt.tick_params(axis='both', labelsize=10, width=1.0)
plt.gca().set_facecolor("#FAFAFA")
plt.box(False)
plt.tight_layout(pad=1.5)

# ===================== 图例设置 =====================
# 上方：类型（颜色）  下方：模块（线条）
type_handles = [
    Patch(facecolor=colors["digital"], edgecolor='black', label='Digital SRAM'),
    Patch(facecolor=colors["ps"], edgecolor='black', label='ps-SRAM'),
    Patch(facecolor=colors["pure"], edgecolor='black', label='Pure SRAM')
]

first_legend = plt.legend(handles=type_handles, fontsize=9, loc='upper right',
                          title="SRAM Type", title_fontsize=10, frameon=True)
plt.gca().add_artist(first_legend)

plt.legend(handles=module_handles, fontsize=8, ncol=4, loc='upper left',
           title="Module Pattern", title_fontsize=9, frameon=True)

# ===================== 输出保存 =====================
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_density_three_types_beautified.svg",
#             format="svg", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
import matplotlib.cm as cm
from matplotlib.colors import to_rgb

# ===================== 基础设置 =====================
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['figure.dpi'] = 150

# ===================== 通用函数 =====================
def load_breakdown(folder, key_density_name):
    files = [f for f in os.listdir(folder) if f.endswith(".json")]
    data_list, breakdowns, modules = [], {}, set()
    for file in files:
        with open(os.path.join(folder, file), "r") as f:
            data = json.load(f)
        label = f"{data['num_rows']}x{data['num_cols']}"
        exclude_keys = [
            "num_rows", "num_cols", "num_muxed_cols", "num_col_muxed",
            "adc_precision", "clt_num", "MUX_Block","MUX_BLOCK","MUX_Bus",
            "MUX","MUX_Decoder","WL_Decoder","Pre_Charge","Pre_charge",
            "SRAM_Write_Driver","Total Area","Used_area","Used Area",
            "Memory_Density (bits/um^2)","Used_memory_Density (bits/um^2)",
            "Used_Memory_Density (bits/um^2)","Used_memory_density (bits/um^2)"
        ]
        breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
        total_area = sum(breakdown.values())
        breakdown = {k: v / total_area for k, v in breakdown.items()}  # 模块占比
        breakdowns[label] = breakdown
        modules.update(breakdown.keys())

        data_list.append({
            "label": label,
            "area": data["num_rows"] * data["num_cols"],
            "density": data[key_density_name]
        })
    data_list.sort(key=lambda d: d["area"])
    return data_list, breakdowns, list(modules)


# ===================== 文件路径 =====================
ps_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
digital_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
pure_folder = "./Data/simulation/pure_sram/mux8/area"

ps_data, ps_break, ps_mod = load_breakdown(ps_folder, "Used_memory_Density (bits/um^2)")
digital_data, digital_break, dig_mod = load_breakdown(digital_folder, "Used_memory_density (bits/um^2)")
pure_data, pure_break, pure_mod = load_breakdown(pure_folder, "Used_Memory_Density (bits/um^2)")

modules = sorted(set(ps_mod + dig_mod + pure_mod))

memory_sizes = [d["label"] for d in ps_data]
ps_density = [d["density"] for d in ps_data]
digital_density = [d["density"] for d in digital_data]
pure_density = [d["density"] for d in pure_data]

# ===================== 配色方案 =====================
# 主色
base_colors = {
    "digital": "#4575B4",  # 柔和蓝
    "ps": "#91BF6D",       # 柔和绿
    "pure": "#FC8D59"      # 柔和红
}

# 模块颜色（Set3 更亮更协调）
cmap = cm.get_cmap('Set3', len(modules))
module_colors = [cmap(i) for i in range(len(modules))]

# 辅助函数：颜色混合（在模块颜色上叠加主色调）
def blend_colors(base_color, module_color, alpha=0.3):
    base_rgb = np.array(to_rgb(base_color))
    mod_rgb = np.array(to_rgb(module_color))
    return tuple((1 - alpha) * mod_rgb + alpha * base_rgb)


# ===================== 绘图 =====================
plt.figure(figsize=(10, 6))
x = np.arange(len(memory_sizes))
bar_width = 0.23

def plot_stacked(breakdowns, densities, offset, label, base_tint):
    bottom = np.zeros(len(memory_sizes))
    for i, module in enumerate(modules):
        vals = [breakdowns.get(size, {}).get(module, 0) * densities[j]
                for j, size in enumerate(memory_sizes)]
        color = blend_colors(base_tint, module_colors[i], alpha=0.25)
        plt.bar(
            x + offset, vals, bar_width,
            bottom=bottom,
            color=color,
            edgecolor='black',
            linewidth=0.7,
            alpha=0.95
        )
        bottom += np.array(vals)
    plt.bar(0, 0, color=base_tint, edgecolor='black', label=label, alpha=0.95)


# 绘制三种 SRAM
plot_stacked(digital_break, digital_density, -bar_width, "Digital SRAM", base_colors["digital"])
plot_stacked(ps_break, ps_density, 0, "ps-SRAM", base_colors["ps"])
plot_stacked(pure_break, pure_density, bar_width, "Pure SRAM", base_colors["pure"])

# ===================== 图例 =====================
module_handles = [
    Patch(facecolor=module_colors[i], edgecolor='black', label=modules[i])
    for i in range(len(modules))
]

type_handles = [
    Patch(facecolor=base_colors["digital"], edgecolor='black', label='Digital SRAM'),
    Patch(facecolor=base_colors["ps"], edgecolor='black', label='ps-SRAM'),
    Patch(facecolor=base_colors["pure"], edgecolor='black', label='Pure SRAM')
]

first_legend = plt.legend(handles=type_handles, fontsize=9, loc='upper right',
                          title="SRAM Type", title_fontsize=10, frameon=True)
plt.gca().add_artist(first_legend)

plt.legend(handles=module_handles, fontsize=8, ncol=4, loc='upper left',
           title="Module Type", title_fontsize=9, frameon=True)

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=8)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=8)
plt.title("Area-Composition Weighted Memory Density Breakdown\n(Digital, ps-, and Pure SRAM, MUX8)",
          fontsize=13, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.6, linewidth=0.7)
plt.tick_params(axis='both', labelsize=10)
plt.gca().set_facecolor("#FAFAFA")
plt.box(False)
plt.tight_layout(pad=1.5)

# ===================== 保存 =====================
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_density_three_types_color_blend.svg", format="svg", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /var/folders/fz/29pbk9_x3cx_bbdhfpt2f2zc0000gn/T/ipykernel_74842/3740154685.py:70: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set3', len(modules))

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
import matplotlib.cm as cm
from matplotlib.colors import to_rgb

# ===================== 基础设置 =====================
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['figure.dpi'] = 150

# ===================== 通用函数 =====================
def load_breakdown(folder, key_density_name):
    files = [f for f in os.listdir(folder) if f.endswith(".json")]
    data_list, breakdowns, modules = [], {}, set()
    for file in files:
        with open(os.path.join(folder, file), "r") as f:
            data = json.load(f)
        label = f"{data['num_rows']}x{data['num_cols']}"
        exclude_keys = [
            "num_rows", "num_cols", "num_muxed_cols", "num_col_muxed",
            "adc_precision", "clt_num", "MUX_Block","MUX_BLOCK","MUX_Bus",
            "MUX","MUX_Decoder","WL_Decoder","Pre_Charge","Pre_charge",
            "SRAM_Write_Driver","Total Area","Used_area","Used Area",
            "Memory_Density (bits/um^2)","Used_memory_Density (bits/um^2)",
            "Used_Memory_Density (bits/um^2)","Used_memory_density (bits/um^2)"
        ]
        breakdown = {k: v for k, v in data.items() if k not in exclude_keys}
        total_area = sum(breakdown.values())
        breakdown = {k: v / total_area for k, v in breakdown.items()}  # 模块占比
        breakdowns[label] = breakdown
        modules.update(breakdown.keys())

        data_list.append({
            "label": label,
            "area": data["num_rows"] * data["num_cols"],
            "density": data[key_density_name]
        })
    data_list.sort(key=lambda d: d["area"])
    return data_list, breakdowns, list(modules)


# ===================== 文件路径 =====================
ps_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/latency"
digital_folder = "./Data/simulation/digital_sram/12CLT/mux8/latency"
# pure_folder = "./Data/simulation/pure_sram/mux8/area"

ps_data, ps_break, ps_mod = load_breakdown(ps_folder, "Total Read Latency (s)")
digital_data, digital_break, dig_mod = load_breakdown(digital_folder, "Total Read Latency (s)")
# pure_data, pure_break, pure_mod = load_breakdown(pure_folder, "Used_Memory_Density (bits/um^2)")

modules = sorted(set(ps_mod + dig_mod))

memory_sizes = [d["label"] for d in ps_data]
ps_density = [d["density"] for d in ps_data]
digital_density = [d["density"] for d in digital_data]
# pure_density = [d["density"] for d in pure_data]

# ===================== 配色方案 =====================
# 主色
base_colors = {
    "digital": "#4575B4",  # 柔和蓝
    "ps": "#91BF6D",       # 柔和绿
    "pure": "#FC8D59"      # 柔和红
}

# 模块颜色（Set3 更亮更协调）
cmap = cm.get_cmap('Set3', len(modules))
module_colors = [cmap(i) for i in range(len(modules))]

# 辅助函数：颜色混合（在模块颜色上叠加主色调）
def blend_colors(base_color, module_color, alpha=0.3):
    base_rgb = np.array(to_rgb(base_color))
    mod_rgb = np.array(to_rgb(module_color))
    return tuple((1 - alpha) * mod_rgb + alpha * base_rgb)


# ===================== 绘图 =====================
plt.figure(figsize=(10, 6))
x = np.arange(len(memory_sizes))
bar_width = 0.23

def plot_stacked(breakdowns, densities, offset, label, base_tint):
    bottom = np.zeros(len(memory_sizes))
    for i, module in enumerate(modules):
        vals = [breakdowns.get(size, {}).get(module, 0) * densities[j]
                for j, size in enumerate(memory_sizes)]
        color = blend_colors(base_tint, module_colors[i], alpha=0.25)
        plt.bar(
            x + offset, vals, bar_width,
            bottom=bottom,
            color=color,
            edgecolor='black',
            linewidth=0.7,
            alpha=0.95
        )
        bottom += np.array(vals)
    plt.bar(0, 0, color=base_tint, edgecolor='black', label=label, alpha=0.95)


# 绘制三种 SRAM
plot_stacked(digital_break, digital_density, -bar_width, "Digital SRAM", base_colors["digital"])
plot_stacked(ps_break, ps_density, 0, "ps-SRAM", base_colors["ps"])
# plot_stacked(pure_break, pure_density, bar_width, "Pure SRAM", base_colors["pure"])

# ===================== 图例 =====================
module_handles = [
    Patch(facecolor=module_colors[i], edgecolor='black', label=modules[i])
    for i in range(len(modules))
]

type_handles = [
    Patch(facecolor=base_colors["digital"], edgecolor='black', label='Digital SRAM'),
    Patch(facecolor=base_colors["ps"], edgecolor='black', label='ps-SRAM')
    # Patch(facecolor=base_colors["pure"], edgecolor='black', label='Pure SRAM')
]

first_legend = plt.legend(handles=type_handles, fontsize=9, loc='upper right',
                          title="SRAM Type", title_fontsize=10, frameon=True)
plt.gca().add_artist(first_legend)

plt.legend(handles=module_handles, fontsize=8, ncol=4, loc='upper left',
           title="Module Type", title_fontsize=9, frameon=True)

# ===================== 图形美化 =====================
plt.xticks(x, memory_sizes, fontsize=10)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=12, labelpad=8)
plt.ylabel("Effective Memory Density (bits/μm²)", fontsize=12, labelpad=8)
plt.title("Area-Composition Weighted Memory Density Breakdown\n(Digital, ps-, and Pure SRAM, MUX8)",
          fontsize=13, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.6, linewidth=0.7)
plt.tick_params(axis='both', labelsize=10)
plt.gca().set_facecolor("#FAFAFA")
plt.box(False)
plt.tight_layout(pad=1.5)

# ===================== 保存 =====================
# os.makedirs("./figure", exist_ok=True)
# plt.savefig("./figure/stacked_density_three_types_color_blend.svg", format="svg", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /var/folders/fz/29pbk9_x3cx_bbdhfpt2f2zc0000gn/T/ipykernel_74842/1345443225.py:70: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set3', len(modules))

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 数据文件目录 =====================
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/latency"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]

digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/latency"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]

# ===================== 读取数据 =====================
data_list_ps, data_list_digital_sram = [], []

for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "latency": data["Total Read Latency (s)"]
    })

for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_digital_sram.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "latency": data["Total Read Latency (s)"]
    })

# ✅ 按阵列面积排序
data_list_ps.sort(key=lambda d: d["area"])
data_list_digital_sram.sort(key=lambda d: d["area"])

# ===================== 提取数据 =====================
memory_sizes = [d["label"] for d in data_list_ps]
latency_ps = [d["latency"] for d in data_list_ps]
latency_digital = [d["latency"] for d in data_list_digital_sram]

# ===================== 绘图 =====================
x = np.arange(len(memory_sizes))
bar_width = 0.35

plt.figure(figsize=(10, 6), dpi=120)

# 🎨 科研统一配色
colors = {
    "digital": "#2C7BB6",  # 蓝 - Digital SRAM
    "ps": "#66C2A5"        # 绿 - ps-SRAM
}

bars1 = plt.bar(x - bar_width/2, latency_digital, width=bar_width,
                label="Digital SRAM", edgecolor='black', color=colors["digital"], alpha=0.9)
bars2 = plt.bar(x + bar_width/2, latency_ps, width=bar_width,
                label="ps-SRAM", edgecolor='black', color=colors["ps"], alpha=0.9)

# # ===================== 数值标注（可选） =====================
# for bars in [bars1, bars2]:
#     for bar in bars:
#         yval = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2, yval * 1.02, f'{yval:.2e}',
#                  ha='center', va='bottom', fontsize=9, rotation=0)

# ===================== 坐标轴与样式优化 =====================
plt.xticks(x, memory_sizes, fontsize=11)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=13, labelpad=10)
plt.ylabel("Total Read Latency (s)", fontsize=13, labelpad=10)
plt.title("Read Latency vs Memory Size (4bitADC-12CLT-MUX8)", fontsize=15, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.legend(frameon=True, fontsize=11)

# ===================== 背景与保存 =====================
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

os.makedirs("./figure", exist_ok=True)
plt.savefig("./figure/latency_comparison_ps_vs_digital_mux8.svg",
            format="svg", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# ===================== 数据文件目录 =====================
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/energy"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]

digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/energy"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]

# ===================== 数据读取 =====================
data_list_ps, data_list_digital_sram = [], []

for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_ps.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "energy": data["Total Read Dynamic Energy (J)"]
    })

for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)
    data_list_digital_sram.append({
        "label": f"{data['num_rows']}x{data['num_cols']}",
        "rows": data["num_rows"],
        "cols": data["num_cols"],
        "area": data["num_rows"] * data["num_cols"],
        "energy": data["Total Read Dynamic Energy (J)"]
    })

# ✅ 按面积从小到大排序
data_list_ps.sort(key=lambda d: d["area"])
data_list_digital_sram.sort(key=lambda d: d["area"])

# ===================== 提取数据 =====================
memory_sizes = [d["label"] for d in data_list_ps]
energy_ps = [d["energy"] for d in data_list_ps]
energy_digital = [d["energy"] for d in data_list_digital_sram]

# ===================== 绘图 =====================
x = np.arange(len(memory_sizes))
bar_width = 0.35

plt.figure(figsize=(11, 6), dpi=120)

# 🎨 科研统一配色
colors = {
    "digital": "#2C7BB6",  # 蓝 - Digital SRAM
    "ps": "#66C2A5"        # 绿 - ps-SRAM
}

bars1 = plt.bar(x - bar_width/2, energy_digital, width=bar_width,
                label="Digital SRAM", edgecolor='black', color=colors["digital"], alpha=0.9)
bars2 = plt.bar(x + bar_width/2, energy_ps, width=bar_width,
                label="ps-SRAM", edgecolor='black', color=colors["ps"], alpha=0.9)

# # ===================== 数值标注 =====================
# for bars in [bars1, bars2]:
#     for bar in bars:
#         yval = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2, yval * 1.03, f'{yval:.2e}',
#                  ha='center', va='bottom', fontsize=9, rotation=0)

# ===================== 坐标轴与样式 =====================
plt.xticks(x, memory_sizes, fontsize=11)
plt.xlabel("Memory Array Size (Rows × Cols)", fontsize=13, labelpad=10)
plt.ylabel("Total Read Dynamic Energy (J)", fontsize=13, labelpad=10)
plt.title("Read Energy vs Memory Size (4bitADC-12CLT-MUX8)", fontsize=15, fontweight='bold', pad=15)

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.legend(frameon=True, fontsize=11)

# ===================== 背景与保存 =====================
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

os.makedirs("./figure", exist_ok=True)
plt.savefig("./figure/energy_comparison_ps_vs_digital_mux8.svg",
            format="svg", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# 数据文件目录
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux16/energy"
ps_sram_files = [f for f in os.listdir(ps_sram_data_folder) if f.endswith(".json")]

pure_sram_data_folder = "./Data/simulation/pure_sram/mux16/energy"
pure_sram_files = [f for f in os.listdir(pure_sram_data_folder) if f.endswith(".json")]

digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux16/energy"
digital_sram_files = [f for f in os.listdir(digital_sram_data_folder) if f.endswith(".json")]


# 临时存储所有数据
data_list_ps = []
data_list_pure_sram = []
data_list_digital_sram = []

# 读取所有 JSON 文件
for file in ps_sram_files:
    filepath = os.path.join(ps_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    energy = data["Total Read Dynamic Energy (J)"]

    data_list_ps.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "energy": energy
    })
for file in pure_sram_files:
    filepath = os.path.join(pure_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    energy = data["Total Read Dynamic Energy (J)"]

    data_list_pure_sram.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "energy": energy
    })
for file in digital_sram_files:
    filepath = os.path.join(digital_sram_data_folder, file)
    with open(filepath, "r") as f:
        data = json.load(f)

    num_rows = data["num_rows"]
    num_cols = data["num_cols"]
    energy = data["Total Read Dynamic Energy (J)"]

    data_list_digital_sram.append({
        "label": f"{num_rows}x{num_cols}",
        "rows": num_rows,
        "cols": num_cols,
        "area": num_rows * num_cols,
        "energy": energy
    })
    

# ✅ 按面积从小到大排序
data_list_ps.sort(key=lambda d: d["area"])
data_list_pure_sram.sort(key=lambda d: d["area"])
data_list_digital_sram.sort(key=lambda d: d["area"])

# 分离数据用于绘图
memory_sizes = [d["label"] for d in data_list_ps]
memory_density_sram_ps = [d["energy"] for d in data_list_ps]

memory_density_sram_pure = [d["energy"] for d in data_list_pure_sram]
memory_density_sram_digital = [d["energy"] for d in data_list_digital_sram]

# 绘图
x = np.arange(len(memory_sizes))
bar_width = 0.4

plt.figure(figsize=(10, 6))
# plt.bar(x - bar_width/3, memory_density_sram_digital, width=bar_width/3, label="Digital SRAM", color="skyblue")
# plt.bar(x, memory_density_sram_ps, width=bar_width/3, label="ps-SRAM", color="lightgreen")
# plt.bar(x + bar_width/3, memory_density_sram_pure, width=bar_width/3, label="Pure SRAM", color="salmon")
plt.bar(x - bar_width/2, memory_density_sram_digital, width=bar_width, label="Digital SRAM", color="skyblue")
plt.bar(x + bar_width/2, memory_density_sram_ps, width=bar_width, label="ps-SRAM", color="lightgreen")

# 坐标轴与标题
plt.xticks(x, memory_sizes)
plt.xlabel("Memory Array Size (Rows × Cols)")
plt.ylabel("Energy (J)")
plt.title("Energy vs Memory Size (4bitADC-12CLT-mux16)")
plt.legend()
plt.grid(True, axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 文件夹路径
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/area"
filename = os.path.join(ps_sram_data_folder, "ps_sram_area_data_512x512.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# 读取 JSON 文件
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Used_area", None)

# 排除元数据
exclude_keys = [
    "num_rows", "num_cols", "num_muxed_cols", "adc_precision",
    "MUX_Bus", "MUX", "MUX_Decoder", "Total Area", "Used_area",
    "Memory_Density (bits/um^2)", "Used_memory_Density (bits/um^2)"
]

area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 如果键名太长，可按长度截断
area_labels = [k if len(k) < 25 else k[:22] + "..." for k in area_data.keys()]
area_values = list(area_data.values())

# 自定义颜色调色板（科技风）
colors = plt.cm.tab20c(range(len(area_data)))  # tab20c: 专业且对比度高

# ==================== 绘图 ====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    area_values,
    labels=area_labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,       # 百分比距离圆心的距离
    labeldistance=1.08,     # 标签距离圆心的距离
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# 百分比字体样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(15)
    autotext.set_fontweight("bold")

# 标签字体样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈样式，更简洁）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# 添加标题
plt.title("Probabilistic Memory Sub-Array Area Breakdown\n(512×512, 4-bit ADC, MUX8)", 
          fontsize=14, fontweight='bold', pad=25)

# 在右下角显示总面积
if total_area is not None:
    plt.text(
        1.2, -1.25,
        f"Total Area = {total_area:.2e} m²",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# 设置背景与比例
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")

plt.tight_layout()

# ==================== 保存为 SVG 文件 ====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, "ps_analog_area_breakdown_512x512_4_bit_ADC_MUX8.svg"), format="svg", dpi=300, bbox_inches="tight")

# 展示图像
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
pure_sram_data_folder = "./Data/simulation/pure_sram/mux8/area"
filename = os.path.join(pure_sram_data_folder, "pure_sram_area_data_512x512.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# ===================== 读取 JSON 数据 =====================
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Used Area", None)

# ===================== 过滤掉元数据 =====================
exclude_keys = [
    "num_rows", "num_cols", "num_col_muxed",
    "MUX_Bus", "MUX", "MUX_Decoder",
    "Total Area", "Used Area",
    "Memory_Density (bits/um^2)", "Used_Memory_Density (bits/um^2)"
]

area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# ===================== 数据处理 =====================
area_labels = [k if len(k) < 25 else k[:22] + "..." for k in area_data.keys()]
area_values = list(area_data.values())

# 使用相同科技风颜色调色板
colors = plt.cm.tab20c(range(len(area_data)))

# ===================== 绘图部分 =====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    area_values,
    labels=area_labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,        # 百分比靠内
    labeldistance=1.08,      # 标签距离圆心
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False             # 去除阴影
)

# ===================== 样式优化 =====================
# 百分比文字样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(15)
    autotext.set_fontweight("bold")

# 标签样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈风格）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与注释 =====================
plt.title("Pure SRAM Sub-Array Area Breakdown\n(512×512, MUX8)", 
          fontsize=14, fontweight='bold', pad=25)

# 显示总面积
if total_area is not None:
    plt.text(
        1.2, -1.25,
        f"Total Area = {total_area:.2e} m²",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与布局 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# # ===================== 保存为 SVG 文件 =====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, "pure_sram_area_breakdown_512x512_MUX8.svg"),
    format="svg", dpi=300, bbox_inches="tight"
)

# ===================== 显示图像 =====================
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/area"
filename = os.path.join(digital_sram_data_folder, "digital_sram_area_data_512x512.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# ===================== 读取 JSON 数据 =====================
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Used Area", None)

# ===================== 过滤掉元数据 =====================
exclude_keys = [
    "num_rows", "num_cols", "clt_num",
    "MUX_Bus", "MUX", "MUX_Decoder",
    "Total Area", "Used Area",
    "Memory_Density (bits/um^2)", "Used_memory_density (bits/um^2)"
]
area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# ===================== 数据处理 =====================
area_labels = [k if len(k) < 25 else k[:22] + "..." for k in area_data.keys()]
area_values = list(area_data.values())

# 自定义配色（科技风，与前面保持一致）
colors = plt.cm.tab20c(range(len(area_data)))

# ===================== 绘图部分 =====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    area_values,
    labels=area_labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,       # 百分比靠内
    labeldistance=1.08,     # 标签靠外
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# ===================== 样式优化 =====================
# 百分比字体样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(15)
    autotext.set_fontweight("bold")

# 标签字体样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈样式）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与注释 =====================
plt.title("Digital SRAM Sub-Array Area Breakdown\n(512×512, MUX8)", 
          fontsize=14, fontweight='bold', pad=25)

# 显示总面积
if total_area is not None:
    plt.text(
        1.2, -1.25,
        f"Total Area = {total_area:.2e} m²",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与布局 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# ===================== 保存为 SVG 文件 =====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, "digital_sram_area_breakdown_512x512_MUX8.svg"),
    format="svg", dpi=300, bbox_inches="tight"
)

# ===================== 显示图像 =====================
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/latency"
filename = os.path.join(data_folder, "ps_sram_latency_data_64x64.json")

# ===================== 文件读取 =====================
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

with open(filename, "r") as f:
    data = json.load(f)

# ===================== 参数自定义 =====================
# 这里根据数据类型修改关键词
main_metric_label = "Total Read Latency (s)"     # 可改为 Energy / Area 等
unit_label = "s"                                 # 单位，例如 "J" 或 "m²"
title_prefix = "Probabilistic Memory Sub-Array Latency Breakdown"
title_suffix = "(64×64, 4-bit ADC, MUX8)"
output_filename = "ps_sram_latency_breakdown_64x64_4bitADC_MUX8.svg"

# ===================== 数据过滤 =====================
total_value = data.get(main_metric_label, None)
exclude_keys = [
    "num_rows", "num_cols", "num_muxed_cols", "adc_precision","MUX_Bus","MUX","MUX_Decoder",
    "Throughput (bits/s)", "Total Read Latency (s)", "Total Read Latency (cycles)",
    "Total Read Dynamic Energy (J)", "Used Area", "Total Area",
    "Memory_Density (bits/um^2)", "Used_memory_density (bits/um^2)"
]

plot_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 标签与数据
labels = [k if len(k) < 25 else k[:22] + "..." for k in plot_data.keys()]
values = list(plot_data.values())

# ===================== 绘图 =====================
plt.figure(figsize=(9, 8), dpi=120)

# 科研风配色方案
colors = plt.cm.tab20c(range(len(plot_data)))

wedges, texts, autotexts = plt.pie(
    values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,
    labeldistance=1.08,
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# ===================== 样式优化 =====================
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(15)
    autotext.set_fontweight("bold")

for text in texts:
    text.set_fontsize(10)

# 添加中心空洞
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与标注 =====================
plt.title(f"{title_prefix}\n{title_suffix}",
          fontsize=14, fontweight='bold', pad=25)

if total_value is not None:
    plt.text(
        1.2, -1.25,
        f"Total = {total_value:.2e} {unit_label}",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与保存 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, output_filename),
    format="svg", dpi=300, bbox_inches="tight"
)

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 文件夹路径
ps_sram_data_folder = "./Data/simulation/pure_sram/mux8/latency"

# 文件名
filename = os.path.join(ps_sram_data_folder, "pure_sram_latency_data_256x256.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# 读取 JSON 文件
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Total Read Latency (s)", None)

# 排除元数据
exclude_keys = [
    "num_rows", "num_cols", "num_col_muxed","MUX_Bus","MUX","MUX_Decoder",
    "Total Read Latency (s)","Throughput (bits/s)", "Total Read Latency (cycles)"
]
area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 绘制饼图
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    area_data.values(),
    labels=area_data.keys(),
    autopct='%1.1f%%',
    startangle=140
)

# 新标题（可自定义）
plt.title("SRAM Memory Sub-Array Latency Breakdown (256×256,  MUX8)", fontsize=14, pad=20)

# 在右下角显示总面积
if total_area is not None:
    plt.text(
        1.3, -1.2,
        f"Total Latency = {total_area:.2e} s",
        fontsize=12,
        ha='right',
        va='center'
    )

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/latency"
filename = os.path.join(digital_sram_data_folder, "digital_sram_latency_data_512x512.json")

# ===================== 检查文件 =====================
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# ===================== 读取 JSON 文件 =====================
with open(filename, "r") as f:
    data = json.load(f)

# ===================== 提取总延迟 =====================
total_latency = data.get("Total Read Latency (s)", None)

# ===================== 排除元数据 =====================
exclude_keys = [
    "num_rows", "num_cols", "clt_num",
    "MUX_Bus", "MUX", "MUX_Decoder",
    "Throughput (bits/s)", "Total Read Latency (s)", "Total Read Latency (cycles)"
]
latency_data = {k: v for k, v in data.items() if k not in exclude_keys}

# ===================== 数据处理 =====================
labels = [k if len(k) < 25 else k[:22] + "..." for k in latency_data.keys()]
values = list(latency_data.values())

# 🎨 自定义配色（与 area breakdown 一致）
colors = plt.cm.tab20c(range(len(latency_data)))

# ===================== 绘图 =====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,       # 百分比距离圆心的距离
    labeldistance=1.08,     # 标签距离圆心的距离
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# ===================== 样式优化 =====================
# 百分比字体样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(13)
    autotext.set_fontweight("bold")

# 标签字体样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈样式）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与注释 =====================
plt.title("Digital SRAM Sub-Array Latency Breakdown\n(512×512, MUX8)", 
          fontsize=14, fontweight='bold', pad=25)

# 显示总延迟
if total_latency is not None:
    plt.text(
        1.2, -1.25,
        f"Total Latency = {total_latency:.2e} s",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与布局 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# ===================== 保存为 SVG 文件 =====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, "digital_sram_latency_breakdown_512x512_MUX8.svg"),
    format="svg", dpi=300, bbox_inches="tight"
)

# ===================== 显示图像 =====================
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 文件夹路径
ps_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/latency"

# 文件名
filename = os.path.join(ps_sram_data_folder, "digital_sram_latency_data_64x64.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# 读取 JSON 文件
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Total Read Latency (s)", None)

# 排除元数据
exclude_keys = [
    "num_rows", "num_cols","clt_num","MUX_Bus","MUX","MUX_Decoder",
    "Total Read Latency (s)","Throughput (bits/s)", "Total Read Latency (cycles)"
]
area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 绘制饼图
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    area_data.values(),
    labels=area_data.keys(),
    autopct='%1.1f%%',
    startangle=140
)

# 新标题（可自定义）
plt.title("Digital Memory Sub-Array Latency Breakdown (64×64, MUX8)", fontsize=14, pad=20)

# 在右下角显示总面积
if total_area is not None:
    plt.text(
        1.3, -1.2,
        f"Total Latency = {total_area:.2e} s",
        fontsize=12,
        ha='right',
        va='center'
    )

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
ps_sram_data_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1/mux8/energy"
filename = os.path.join(ps_sram_data_folder, "ps_sram_energy_data_512x512.json")

# ===================== 检查文件 =====================
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# ===================== 读取 JSON 文件 =====================
with open(filename, "r") as f:
    data = json.load(f)

# ===================== 提取总能量 =====================
total_energy = data.get("Total Read Dynamic Energy (J)", None)

# ===================== 过滤掉非能量项 =====================
exclude_keys = [
    "num_rows", "num_cols", "num_muxed_cols", "adc_precision","MUX_Bus","MUX","MUX_Decoder",
    "wl_decoder_leakage", "precharger_leakage", "sram_write_driver_leakage",
    "Total Read Dynamic Energy (J)", "Leakage Power (W)"
]
energy_data = {k: v for k, v in data.items() if k not in exclude_keys}

# ===================== 数据处理 =====================
labels = [k if len(k) < 25 else k[:22] + "..." for k in energy_data.keys()]
values = list(energy_data.values())

# 🎨 科研统一配色（tab20c）
colors = plt.cm.tab20c(range(len(energy_data)))

# ===================== 绘图 =====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,      # 百分比内缩位置
    labeldistance=1.08,    # 标签外扩位置
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# ===================== 样式优化 =====================
# 百分比字体样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(13)
    autotext.set_fontweight("bold")

# 标签字体样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈图样式）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与注释 =====================
plt.title("Probabilistic SRAM Sub-Array Energy Breakdown\n(512×512, 4-bit ADC, MUX8)",
          fontsize=14, fontweight='bold', pad=25)

# 显示总能量
if total_energy is not None:
    plt.text(
        1.2, -1.25,
        f"Total Energy = {total_energy:.2e} J",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与布局 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# ===================== 保存为 SVG 文件 =====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, "ps_sram_energy_breakdown_512x512_4bitADC_MUX8.svg"),
    format="svg", dpi=300, bbox_inches="tight"
)

# ===================== 显示图像 =====================
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 文件夹路径
ps_sram_data_folder = "./Data/simulation/pure_sram/mux8/energy"

# 文件名
filename = os.path.join(ps_sram_data_folder, "pure_sram_energy_data_256x256.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# 读取 JSON 文件
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Total Read Dynamic Energy (J)", None)

# 排除元数据
exclude_keys = [
    "num_rows", "num_cols", "num_col_muxed","wl_decoder_leakage", "precharger_leakage", "sram_write_driver_leakage",
    "Total Read Dynamic Energy (J)", "Leakage Power (W)"
]
area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 绘制饼图
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    area_data.values(),
    labels=area_data.keys(),
    autopct='%1.1f%%',
    startangle=140
)

# 新标题（可自定义）
plt.title("SRAM Memory Sub-Array Energy Breakdown (256×256, 3-bit ADC, MUX8)", fontsize=14, pad=20)

# 在右下角显示总面积
if total_area is not None:
    plt.text(
        1.3, -1.2,
        f"Total Energy = {total_area:.2e} J",
        fontsize=12,
        ha='right',
        va='center'
    )

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# ===================== 文件路径 =====================
digital_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/energy"
filename = os.path.join(digital_sram_data_folder, "digital_sram_energy_data_64x64.json")

# ===================== 文件检查 =====================
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# ===================== 读取 JSON 文件 =====================
with open(filename, "r") as f:
    data = json.load(f)

# ===================== 提取总能量 =====================
total_energy = data.get("Total Read Dynamic Energy (J)", None)

# ===================== 过滤非能量字段 =====================
exclude_keys = [
    "num_rows", "num_cols", "clt_num",
    "MUX_Bus", "MUX", "MUX_Decoder",
    "Total Read Dynamic Energy (J)"
]
energy_data = {k: v for k, v in data.items() if k not in exclude_keys}

# ===================== 数据处理 =====================
labels = [k if len(k) < 25 else k[:22] + "..." for k in energy_data.keys()]
values = list(energy_data.values())

# 🎨 统一科研配色方案（tab20c）
colors = plt.cm.tab20c(range(len(energy_data)))

# ===================== 绘制饼图 =====================
plt.figure(figsize=(9, 8), dpi=120)

wedges, texts, autotexts = plt.pie(
    values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.78,       # 百分比距离圆心距离
    labeldistance=1.08,     # 标签距离圆心距离
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2},
    shadow=False
)

# ===================== 样式优化 =====================
# 百分比文字样式
for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(13)
    autotext.set_fontweight("bold")

# 标签文字样式
for text in texts:
    text.set_fontsize(10)

# 添加中心空洞（甜甜圈效果）
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
plt.gca().add_artist(centre_circle)

# ===================== 标题与标注 =====================
plt.title("Digital SRAM Sub-Array Energy Breakdown\n(64×64, MUX8)",
          fontsize=14, fontweight='bold', pad=25)

# 显示总能量
if total_energy is not None:
    plt.text(
        1.2, -1.25,
        f"Total Energy = {total_energy:.2e} J",
        fontsize=11,
        ha='right',
        va='center',
        style='italic'
    )

# ===================== 背景与布局 =====================
plt.gca().set_aspect('equal')
plt.gca().set_facecolor("#F9F9F9")
plt.tight_layout()

# ===================== 保存为 SVG 文件 =====================
output_dir = "./figure"
os.makedirs(output_dir, exist_ok=True)
plt.savefig(
    os.path.join(output_dir, "digital_sram_energy_breakdown_64x64_MUX8.svg"),
    format="svg", dpi=300, bbox_inches="tight"
)

# ===================== 显示图像 =====================
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 文件夹路径
ps_sram_data_folder = "./Data/simulation/digital_sram/12CLT/mux8/energy"

# 文件名
filename = os.path.join(ps_sram_data_folder, "digital_sram_energy_data_256x256.json")

# 检查文件是否存在
if not os.path.exists(filename):
    raise FileNotFoundError(f"找不到文件: {filename}")

# 读取 JSON 文件
with open(filename, "r") as f:
    data = json.load(f)

# 提取总面积
total_area = data.get("Total Read Dynamic Energy (J)", None)

# 排除元数据
exclude_keys = [
    "num_rows", "num_cols", "clt_num",
    "MUX_Bus", "MUX", "MUX_Decoder",
    "Total Read Dynamic Energy (J)"
]
area_data = {k: v for k, v in data.items() if k not in exclude_keys}

# 绘制饼图
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    area_data.values(),
    labels=area_data.keys(),
    autopct='%1.1f%%',
    startangle=140
)

# 新标题（可自定义）
plt.title("Digital Memory Sub-Array Energy Breakdown (256×256, MUX8)", fontsize=14, pad=20)

# 在右下角显示总面积
if total_area is not None:
    plt.text(
        1.3, -1.2,
        f"Total Energy = {total_area:.2e} J",
        fontsize=12,
        ha='right',
        va='center'
    )

plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# 要比较的 ADC 精度
adc_precisions = ["2bitADC", "4bitADC", "6bitADC"]

# 基础路径
base_folder = "./Data/simulation/ps_sram"

# 用于存储不同 ADC 精度的数据
adc_data_dict = {}

# 读取每个 ADC 精度的数据
for adc in adc_precisions:
    adc_folder = os.path.join(base_folder, adc, "ARNG1", "mux8", "area")
    adc_files = [f for f in os.listdir(adc_folder) if f.endswith(".json")]
    data_list = []

    for file in adc_files:
        filepath = os.path.join(adc_folder, file)
        with open(filepath, "r") as f:
            data = json.load(f)

        num_rows = data["num_rows"]
        num_cols = data["num_cols"]
        density = data["Used_memory_Density (bits/um^2)"]

        data_list.append({
            "label": f"{num_rows}x{num_cols}",
            "rows": num_rows,
            "cols": num_cols,
            "area": num_rows * num_cols,
            "density": density
        })

    # 按面积排序（确保一致）
    data_list.sort(key=lambda d: d["area"])
    adc_data_dict[adc] = data_list

# 获取所有 memory 尺寸标签（以 3bit 为基准）
memory_sizes = [d["label"] for d in adc_data_dict[adc_precisions[0]]]

# 准备绘图
x = np.arange(len(memory_sizes))
bar_width = 0.25

plt.figure(figsize=(10, 6))

# 画出每个 ADC 精度的柱子
for i, adc in enumerate(adc_precisions):
    memory_density = [d["density"] for d in adc_data_dict[adc]]
    plt.bar(x + (i - 1) * bar_width, memory_density, width=bar_width, label=adc)

# 坐标轴与标题
plt.xticks(x, memory_sizes)
plt.xlabel("Memory Array Size (Rows × Cols)")
plt.ylabel("Used Memory Density (bits/μm²)")
plt.title("Used Memory Density vs Memory Size for Different ADC Precisions (ARNG1, MUX8)")
plt.legend()
plt.grid(True, axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# 定义要比较的 ADC 精度
adc_precisions = ["2bitADC", "4bitADC", "6bitADC"]

# 基础路径
base_folder = "./Data/simulation/ps_sram"

# 存储每种 ADC 精度的数据
adc_data_dict = {}

# 读取各 ADC 精度的数据
for adc in adc_precisions:
    adc_folder = os.path.join(base_folder, adc, "ARNG1", "mux8", "latency")
    adc_files = [f for f in os.listdir(adc_folder) if f.endswith(".json")]
    data_list = []

    for file in adc_files:
        filepath = os.path.join(adc_folder, file)
        with open(filepath, "r") as f:
            data = json.load(f)

        num_rows = data["num_rows"]
        num_cols = data["num_cols"]
        latency = data["Total Read Latency (s)"]

        data_list.append({
            "label": f"{num_rows}x{num_cols}",
            "rows": num_rows,
            "cols": num_cols,
            "area": num_rows * num_cols,
            "latency": latency
        })

    # 按面积排序，保证一致顺序
    data_list.sort(key=lambda d: d["area"])
    adc_data_dict[adc] = data_list

# 使用第一个 ADC 精度的尺寸标签（假设一致）
memory_sizes = [d["label"] for d in adc_data_dict[adc_precisions[0]]]

# 绘制柱状图
x = np.arange(len(memory_sizes))
bar_width = 0.25

plt.figure(figsize=(10, 6))

for i, adc in enumerate(adc_precisions):
    latencies = [d["latency"] for d in adc_data_dict[adc]]
    plt.bar(x + (i - 1) * bar_width, latencies, width=bar_width, label=adc)

# 坐标轴与标题
plt.xticks(x, memory_sizes)
plt.xlabel("Memory Array Size (Rows × Cols)")
plt.ylabel("Total Read Latency (s)")
plt.title("Read Latency vs Memory Size for Different ADC Precisions (ARNG1, MUX8)")
plt.legend()
plt.grid(True, axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# 定义要比较的 ADC 精度
adc_precisions = ["2bitADC", "4bitADC", "6bitADC"]

# 基础路径
base_folder = "./Data/simulation/ps_sram"

# 存储每种 ADC 精度的数据
adc_data_dict = {}

# 读取各 ADC 精度的数据
for adc in adc_precisions:
    adc_folder = os.path.join(base_folder, adc, "ARNG1", "mux8", "energy")
    adc_files = [f for f in os.listdir(adc_folder) if f.endswith(".json")]
    data_list = []

    for file in adc_files:
        filepath = os.path.join(adc_folder, file)
        with open(filepath, "r") as f:
            data = json.load(f)

        num_rows = data["num_rows"]
        num_cols = data["num_cols"]
        energy = data["Total Read Dynamic Energy (J)"]

        data_list.append({
            "label": f"{num_rows}x{num_cols}",
            "rows": num_rows,
            "cols": num_cols,
            "area": num_rows * num_cols,
            "energy": energy
        })

    # 按面积排序（保证一致）
    data_list.sort(key=lambda d: d["area"])
    adc_data_dict[adc] = data_list

# 使用第一个 ADC 精度的阵列尺寸作为 X 轴标签
memory_sizes = [d["label"] for d in adc_data_dict[adc_precisions[0]]]

# 绘制柱状图
x = np.arange(len(memory_sizes))
bar_width = 0.25

plt.figure(figsize=(10, 6))

for i, adc in enumerate(adc_precisions):
    energies = [d["energy"] for d in adc_data_dict[adc]]
    plt.bar(x + (i - 1) * bar_width, energies, width=bar_width, label=adc)

# 坐标轴与标题
plt.xticks(x, memory_sizes)
plt.xlabel("Memory Array Size (Rows × Cols)")
plt.ylabel("Total Read Dynamic Energy (J)")
plt.title("Read Energy vs Memory Size for Different ADC Precisions (ARNG1, MUX8)")
plt.legend()
plt.grid(True, axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import os
import json
import matplotlib.pyplot as plt

# 基础路径
base_folder = "./Data/simulation/digital_sram/12CLT"

# 定义要比较的 MUX 比率
mux_ratios = ["mux1","mux2","mux4", "mux8", "mux16"]  # 可根据实际文件夹修改

# 存储结果
results = []

# 遍历不同 MUX 比率
for mux in mux_ratios:
    # 提取 mux 数值 (如 "mux8" -> 8)
    mux_value = int(mux.replace("mux", ""))
    
    # 文件路径
    area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
    latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")
    
    # 检查文件存在
    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        print(f"⚠️ 跳过 {mux} （文件缺失）")
        continue

    # 读取 area 文件
    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used Area", None)
    num_cols = area_data.get("num_cols", None)

    # 读取 latency 文件
    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None)

    # 计算带宽
    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results.append({
            "mux": mux,
            "mux_value": mux_value,
            "area": total_area,
            "latency": total_latency,
            "bandwidth": bandwidth
        })

# 输出结果检查
for r in results:
    print(f"{r['mux']}: Area={r['area']:.2e}, Latency={r['latency']:.2e}, Bandwidth={r['bandwidth']:.2e}")

# 提取用于绘图
mux_labels = [r["mux"] for r in results]
areas = [r["area"] for r in results]
bandwidths = [r["bandwidth"] for r in results]

# 绘制 Bandwidth vs Area 散点图
plt.figure(figsize=(8, 6))
plt.scatter(areas, bandwidths, s=80)

# 添加标注（MUX 标签）
for i, mux in enumerate(mux_labels):
    plt.text(areas[i] * 1.03, bandwidths[i], mux, fontsize=9)

# 图形设置
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Different MUX Ratios (Digital SRAM, 3bitADC, 12CLT, 128×128)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# mux1: Area=9.47e-08, Latency=1.95e-08, Bandwidth=6.55e+09
# mux2: Area=5.46e-08, Latency=2.43e-08, Bandwidth=2.64e+09
# mux4: Area=3.45e-08, Latency=2.29e-08, Bandwidth=1.40e+09
# mux8: Area=2.45e-08, Latency=2.22e-08, Bandwidth=7.22e+08
# mux16: Area=1.96e-08, Latency=2.20e-08, Bandwidth=3.64e+08

# %%
import os
import json
import matplotlib.pyplot as plt

# 基础路径
base_folder = "./Data/simulation/digital_sram/12CLT"

# 定义要比较的 MUX 比率
mux_ratios = ["mux1","mux2","mux4", "mux8", "mux16"]  # 可根据实际文件夹修改

# 存储结果
results = []

# 遍历不同 MUX 比率
for mux in mux_ratios:
    # 提取 mux 数值 (如 "mux8" -> 8)
    mux_value = int(mux.replace("mux", ""))
    
    # 文件路径
    area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
    latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")
    
    # 检查文件存在
    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        print(f"⚠️ 跳过 {mux} （文件缺失）")
        continue

    # 读取 area 文件
    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used Area", None)
    num_cols = area_data.get("num_cols", None)

    # 读取 latency 文件
    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None) * mux_value

    # 计算带宽
    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results.append({
            "mux": mux,
            "mux_value": mux_value,
            "area": total_area,
            "latency": total_latency,
            "bandwidth": bandwidth
        })

# 输出结果检查
for r in results:
    print(f"{r['mux']}: Area={r['area']:.2e}, Latency={r['latency']:.2e}, Bandwidth={r['bandwidth']:.2e}")

# 提取用于绘图
mux_labels = [r["mux"] for r in results]
areas = [r["area"] for r in results]
bandwidths = [r["bandwidth"] for r in results]
latencies = [r["latency"] for r in results]

# 绘制 Bandwidth vs Area 散点图
plt.figure(figsize=(8, 6))
plt.scatter(areas, latencies, s=80)

# 添加标注（MUX 标签）
for i, mux in enumerate(mux_labels):
    plt.text(areas[i] * 1.03, latencies[i], mux, fontsize=9)

# 图形设置
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Different MUX Ratios (Digital SRAM, 3bitADC, 12CLT, 128×128)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# mux1: Area=9.47e-08, Latency=1.95e-08, Bandwidth=6.55e+09
# mux2: Area=5.46e-08, Latency=4.85e-08, Bandwidth=1.32e+09
# mux4: Area=3.45e-08, Latency=9.17e-08, Bandwidth=3.49e+08
# mux8: Area=2.45e-08, Latency=1.77e-07, Bandwidth=9.03e+07
# mux16: Area=1.96e-08, Latency=3.52e-07, Bandwidth=2.27e+07

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------
# 你的已有代码
# --------------------------
base_folder = "./Data/simulation/digital_sram/12CLT"
mux_ratios = ["mux1","mux2","mux4","mux8","mux16"]
results = []

for mux in mux_ratios:
    mux_value = int(mux.replace("mux", ""))
    area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
    latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        print(f"⚠️ 跳过 {mux} （文件缺失）")
        continue

    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used Area", None)
    num_cols = area_data.get("num_cols", None)

    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None)

    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results.append({
            "mux": mux,
            "mux_value": mux_value,
            "area": total_area,
            "bandwidth": bandwidth
        })

# 转换为 numpy 数组
areas = np.array([r["area"] for r in results])
bandwidths = np.array([r["bandwidth"] for r in results])

# 根据面积从小到大排序，防止曲线乱连
sorted_idx = np.argsort(areas)
areas = areas[sorted_idx]
bandwidths = bandwidths[sorted_idx]
mux_labels = [results[i]["mux"] for i in sorted_idx]

# =============================
# 多项式拟合（degree=2 or 3）
# =============================
fit_coeffs = np.polyfit(areas, bandwidths, deg=4)
fit_poly = np.poly1d(fit_coeffs)

# 生成平滑曲线点
x_fit = np.linspace(areas.min(), areas.max(), 200)
y_fit = fit_poly(x_fit)

# =============================
# 绘图部分
# =============================
plt.figure(figsize=(8, 6))
plt.scatter(areas, bandwidths, s=80, label="Measured Points")
plt.plot(x_fit, y_fit, '-', linewidth=2, label=f"Polynomial Fit (deg=2)")

# 标注 MUX 标签
for i, mux in enumerate(mux_labels):
    plt.text(areas[i]*1.02, bandwidths[i], mux, fontsize=9)

plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area (with Polynomial Fit)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

print("拟合方程：")
print(f"Bandwidth ≈ {fit_coeffs[0]:.2e} * Area² + {fit_coeffs[1]:.2e} * Area + {fit_coeffs[2]:.2e}")
# Out:
# 拟合方程：
# Bandwidth ≈ 8.85e+37 * Area² + -7.32e+30 * Area + -1.34e+23

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------
# 你的已有代码
# --------------------------
base_folder = "./Data/simulation/digital_sram/12CLT"
mux_ratios = ["mux1","mux2","mux4","mux8","mux16"]
results = []

for mux in mux_ratios:
    mux_value = int(mux.replace("mux", ""))
    area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
    latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        print(f"⚠️ 跳过 {mux} （文件缺失）")
        continue

    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used Area", None)
    num_cols = area_data.get("num_cols", None)

    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None) * mux_value

    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results.append({
            "mux": mux,
            "mux_value": mux_value,
            "area": total_area,
            "total_latency": total_latency,
            "bandwidth": bandwidth
        })

# 转换为 numpy 数组
areas = np.array([r["area"] for r in results])
bandwidths = np.array([r["bandwidth"] for r in results])
latencies = np.array([r["total_latency"] for r in results])

# 根据面积从小到大排序，防止曲线乱连
sorted_idx = np.argsort(areas)
areas = areas[sorted_idx]
bandwidths = bandwidths[sorted_idx]
latencies = latencies[sorted_idx]
mux_labels = [results[i]["mux"] for i in sorted_idx]

# =============================
# 多项式拟合（degree=2 or 3）
# =============================
fit_coeffs = np.polyfit(areas, latencies, deg=15)
fit_poly = np.poly1d(fit_coeffs)

# 生成平滑曲线点
x_fit = np.linspace(areas.min(), areas.max(), 200)
y_fit = fit_poly(x_fit)

# =============================
# 绘图部分
# =============================
plt.figure(figsize=(8, 6))
plt.scatter(areas, latencies, s=80, label="Measured Points")
plt.plot(x_fit, y_fit, '-', linewidth=2, label=f"Polynomial Fit (deg=2)")

# 标注 MUX 标签
for i, mux in enumerate(mux_labels):
    plt.text(areas[i]*1.02, latencies[i], mux, fontsize=9)

plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area (with Polynomial Fit)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

print("拟合方程：")
print(f"Bandwidth ≈ {fit_coeffs[0]:.2e} * Area² + {fit_coeffs[1]:.2e} * Area + {fit_coeffs[2]:.2e}")
# Out:
# /var/folders/fz/29pbk9_x3cx_bbdhfpt2f2zc0000gn/T/ipykernel_74842/270503294.py:55: RankWarning: Polyfit may be poorly conditioned
#   fit_coeffs = np.polyfit(areas, latencies, deg=15)
# 拟合方程：
# Bandwidth ≈ 1.19e+100 * Area² + 1.10e+93 * Area + 9.90e+85

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------
# 你的已有代码
# --------------------------
base_folder = "./Data/simulation/ps_sram/4bitADC/ARNG1"
mux_ratios = ["mux1","mux2","mux4","mux8","mux16"]
results = []

for mux in mux_ratios:
    mux_value = int(mux.replace("mux", ""))
    area_path = os.path.join(base_folder, mux, "area", "ps_sram_area_data_128x128.json")
    latency_path = os.path.join(base_folder, mux, "latency", "ps_sram_latency_data_128x128.json")

    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        print(f"⚠️ 跳过 {mux} （文件缺失）")
        continue

    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used_area", None)
    num_cols = area_data.get("num_cols", None)

    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None)

    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results.append({
            "mux": mux,
            "mux_value": mux_value,
            "area": total_area,
            "bandwidth": bandwidth
        })

# 转换为 numpy 数组
areas = np.array([r["area"] for r in results])
bandwidths = np.array([r["bandwidth"] for r in results])

# 根据面积从小到大排序，防止曲线乱连
sorted_idx = np.argsort(areas)
areas = areas[sorted_idx]
bandwidths = bandwidths[sorted_idx]
mux_labels = [results[i]["mux"] for i in sorted_idx]

# =============================
# 多项式拟合（degree=2 or 3）
# =============================
fit_coeffs = np.polyfit(areas, bandwidths, deg=4)
fit_poly = np.poly1d(fit_coeffs)

# 生成平滑曲线点
x_fit = np.linspace(areas.min(), areas.max(), 200)
y_fit = fit_poly(x_fit)

# =============================
# 绘图部分
# =============================
plt.figure(figsize=(8, 6))
plt.scatter(areas, bandwidths, s=80, label="Measured Points")
plt.plot(x_fit, y_fit, '-', linewidth=2, label=f"Polynomial Fit (deg=2)")

# 标注 MUX 标签
for i, mux in enumerate(mux_labels):
    plt.text(areas[i]*1.02, bandwidths[i], mux, fontsize=9)

plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area (with Polynomial Fit)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

print("拟合方程：")
print(f"Bandwidth ≈ {fit_coeffs[0]:.2e} * Area² + {fit_coeffs[1]:.2e} * Area + {fit_coeffs[2]:.2e}")
# Out:
# 拟合方程：
# Bandwidth ≈ 1.12e+40 * Area² + -4.25e+31 * Area + -3.69e+25

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------
# 参数定义
# --------------------------
base_root = "./Data/simulation/digital_sram"
clt_values = [ "4CLT", "6CLT", "8CLT", "12CLT"]
mux_ratios = ["mux1", "mux2", "mux4", "mux8", "mux16"]

# 定义颜色映射
colors = plt.cm.viridis(np.linspace(0, 1, len(clt_values)))

# --------------------------
# 绘图初始化
# --------------------------
plt.figure(figsize=(9, 6))

# --------------------------
# 遍历每个 CLT 配置
# --------------------------
for color, clt in zip(colors, clt_values):
    base_folder = os.path.join(base_root, clt)
    results = []

    for mux in mux_ratios:
        mux_value = int(mux.replace("mux", ""))
        area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
        latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

        if not (os.path.exists(area_path) and os.path.exists(latency_path)):
            print(f"⚠️ 跳过 {clt} - {mux} （文件缺失）")
            continue

        with open(area_path, "r") as f:
            area_data = json.load(f)
        total_area = area_data.get("Used Area", None)
        num_cols = area_data.get("num_cols", None)

        with open(latency_path, "r") as f:
            latency_data = json.load(f)
        total_latency = latency_data.get("Total Read Latency (s)", None)

        if total_area and total_latency and num_cols:
            bandwidth = num_cols / (mux_value * total_latency)
            results.append({
                "mux": mux,
                "area": total_area,
                "bandwidth": bandwidth
            })

    # 如果当前 CLT 有数据，则处理
    if len(results) > 0:
        # 排序
        results.sort(key=lambda r: r["area"])
        areas = np.array([r["area"] for r in results])
        bandwidths = np.array([r["bandwidth"] for r in results])

        # 多项式拟合（可改 deg=3）
        fit_coeffs = np.polyfit(areas, bandwidths, deg=3)
        fit_poly = np.poly1d(fit_coeffs)

        x_fit = np.linspace(areas.min(), areas.max(), 200)
        y_fit = fit_poly(x_fit)

        # 绘制散点 + 曲线
        plt.scatter(areas, bandwidths, color=color, s=40)
        plt.plot(x_fit, y_fit, '-', color=color, linewidth=2, label=f"{clt}")

# --------------------------
# 绘图修饰
# --------------------------
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Different CLT Configurations (Digital SRAM, 3bitADC, 128×128)")
plt.legend(title="CLT")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------
# 参数定义
# --------------------------
base_root = "./Data/simulation/digital_sram"
clt_values = [ "4CLT", "6CLT", "8CLT", "12CLT"]
mux_ratios = ["mux1", "mux2", "mux4", "mux8", "mux16"]

# 定义颜色映射
colors = plt.cm.viridis(np.linspace(0, 1, len(clt_values)))

# --------------------------
# 绘图初始化
# --------------------------
plt.figure(figsize=(9, 6))

# --------------------------
# 遍历每个 CLT 配置
# --------------------------
for color, clt in zip(colors, clt_values):
    base_folder = os.path.join(base_root, clt)
    results = []

    for mux in mux_ratios:
        mux_value = int(mux.replace("mux", ""))
        area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
        latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

        if not (os.path.exists(area_path) and os.path.exists(latency_path)):
            print(f"⚠️ 跳过 {clt} - {mux} （文件缺失）")
            continue

        with open(area_path, "r") as f:
            area_data = json.load(f)
        total_area = area_data.get("Used Area", None)
        num_cols = area_data.get("num_cols", None)

        with open(latency_path, "r") as f:
            latency_data = json.load(f)
        total_latency = latency_data.get("Total Read Latency (s)", None) * mux_value

        if total_area and total_latency and num_cols:
            bandwidth = num_cols / (mux_value * total_latency)
            results.append({
                "mux": mux,
                "area": total_area,
                "total_latency": total_latency
            })

    # 如果当前 CLT 有数据，则处理
    if len(results) > 0:
        # 排序
        results.sort(key=lambda r: r["area"])
        areas = np.array([r["area"] for r in results])
        bandwidths = np.array([r["total_latency"] for r in results])

        # 多项式拟合（可改 deg=3）
        fit_coeffs = np.polyfit(areas, bandwidths, deg=3)
        fit_poly = np.poly1d(fit_coeffs)

        x_fit = np.linspace(areas.min(), areas.max(), 200)
        y_fit = fit_poly(x_fit)

        # 绘制散点 + 曲线
        plt.scatter(areas, bandwidths, color=color, s=40)
        plt.plot(x_fit, y_fit, '-', color=color, linewidth=2, label=f"{clt}")

# --------------------------
# 绘图修饰
# --------------------------
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Different CLT Configurations (Digital SRAM, 3bitADC, 128×128)")
plt.legend(title="CLT")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------------------
# 1️⃣ Digital SRAM (多CLT)
# --------------------------------------
digital_root = "./Data/simulation/digital_sram"
clt_values = ["2CLT", "4CLT", "6CLT", "8CLT", "12CLT"]
mux_ratios = ["mux1", "mux2", "mux4", "mux8", "mux16"]

colors = plt.cm.viridis(np.linspace(0, 1, len(clt_values)))
plt.figure(figsize=(9, 6))

for color, clt in zip(colors, clt_values):
    base_folder = os.path.join(digital_root, clt)
    results = []

    for mux in mux_ratios:
        mux_value = int(mux.replace("mux", ""))
        area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
        latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

        if not (os.path.exists(area_path) and os.path.exists(latency_path)):
            continue

        with open(area_path, "r") as f:
            area_data = json.load(f)
        total_area = area_data.get("Used Area", None)
        num_cols = area_data.get("num_cols", None)

        with open(latency_path, "r") as f:
            latency_data = json.load(f)
        total_latency = latency_data.get("Total Read Latency (s)", None)

        if total_area and total_latency and num_cols:
            bandwidth = num_cols / (mux_value * total_latency)
            results.append({
                "mux": mux,
                "area": total_area,
                "bandwidth": bandwidth
            })

    if len(results) > 0:
        # 按面积排序
        results.sort(key=lambda r: r["area"])
        areas = np.array([r["area"] for r in results])
        bandwidths = np.array([r["bandwidth"] for r in results])

        # 多项式拟合 (三阶)
        fit_coeffs = np.polyfit(areas, bandwidths, deg=3)
        fit_poly = np.poly1d(fit_coeffs)
        x_fit = np.linspace(areas.min(), areas.max(), 200)
        y_fit = fit_poly(x_fit)

        # 绘制散点 + 曲线
        plt.scatter(areas, bandwidths, s=40, color=color)
        plt.plot(x_fit, y_fit, '-', linewidth=2, color=color, label=f"{clt}")

# --------------------------------------
# 2️⃣ Analog RNG (ps_sram)
# --------------------------------------
ps_sram_base = "./Data/simulation/ps_sram/4bitADC/ARNG1"
results_ps = []

for mux in mux_ratios:
    mux_value = int(mux.replace("mux", ""))
    area_path = os.path.join(ps_sram_base, mux, "area", "ps_sram_area_data_128x128.json")
    latency_path = os.path.join(ps_sram_base, mux, "latency", "ps_sram_latency_data_128x128.json")

    if not (os.path.exists(area_path) and os.path.exists(latency_path)):
        continue

    with open(area_path, "r") as f:
        area_data = json.load(f)
    total_area = area_data.get("Used_area", None)
    num_cols = area_data.get("num_cols", None)

    with open(latency_path, "r") as f:
        latency_data = json.load(f)
    total_latency = latency_data.get("Total Read Latency (s)", None)

    if total_area and total_latency and num_cols:
        bandwidth = num_cols / (mux_value * total_latency)
        results_ps.append({
            "mux": mux,
            "area": total_area,
            "bandwidth": bandwidth
        })

# 处理 ps_sram 数据
if len(results_ps) > 0:
    results_ps.sort(key=lambda r: r["area"])
    areas_ps = np.array([r["area"] for r in results_ps])
    bandwidths_ps = np.array([r["bandwidth"] for r in results_ps])

    # 样条或多项式拟合
    fit_coeffs_ps = np.polyfit(areas_ps, bandwidths_ps, deg=3)
    fit_poly_ps = np.poly1d(fit_coeffs_ps)
    x_fit_ps = np.linspace(areas_ps.min(), areas_ps.max(), 200)
    y_fit_ps = fit_poly_ps(x_fit_ps)

    plt.scatter(areas_ps, bandwidths_ps, s=60, color="red", marker="o")
    plt.plot(x_fit_ps, y_fit_ps, "--", color="red", linewidth=2.2, label="Analog RNG (ps-SRAM)")

# --------------------------------------
# 3️⃣ 图形美化
# --------------------------------------
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Digital CLT and Analog RNG (4bitADC, 128×128)")
plt.legend(title="Configuration")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import json, os

# --------------------------------------
# 1️⃣ Digital SRAM (多CLT)
# --------------------------------------
digital_root = "./Data/simulation/digital_sram"
clt_values = ["2CLT", "4CLT", "6CLT", "8CLT", "12CLT"]
mux_ratios = ["mux1", "mux2", "mux4", "mux8", "mux16"]

colors = plt.cm.viridis(np.linspace(0, 1, len(clt_values)))
plt.figure(figsize=(9, 6))

for color, clt in zip(colors, clt_values):
    base_folder = os.path.join(digital_root, clt)
    results = []

    for mux in mux_ratios:
        mux_value = int(mux.replace("mux", ""))
        area_path = os.path.join(base_folder, mux, "area", "digital_sram_area_data_128x128.json")
        latency_path = os.path.join(base_folder, mux, "latency", "digital_sram_latency_data_128x128.json")

        if not (os.path.exists(area_path) and os.path.exists(latency_path)):
            continue

        with open(area_path, "r") as f:
            area_data = json.load(f)
        total_area = area_data.get("Used Area", None)
        num_cols = area_data.get("num_cols", None)

        with open(latency_path, "r") as f:
            latency_data = json.load(f)
        total_latency = latency_data.get("Total Read Latency (s)", None)

        if total_area and total_latency and num_cols:
            bandwidth = num_cols / (mux_value * total_latency)
            results.append({
                "mux": mux,
                "area": total_area,
                "bandwidth": bandwidth
            })

    if len(results) > 0:
        # 按面积排序
        results.sort(key=lambda r: r["area"])
        areas = np.array([r["area"] for r in results])
        bandwidths = np.array([r["bandwidth"] for r in results])

        # 多项式拟合 (三阶)
        fit_coeffs = np.polyfit(areas, bandwidths, deg=3)
        fit_poly = np.poly1d(fit_coeffs)
        x_fit = np.linspace(areas.min(), areas.max(), 200)
        y_fit = fit_poly(x_fit)

        # 绘制散点 + 曲线
        plt.scatter(areas, bandwidths, s=40, color=color)
        plt.plot(x_fit, y_fit, '-', linewidth=2, color=color, label=f"{clt}")

# --------------------------------------
# 2️⃣ Analog RNG (ps_sram) — 支持多 ADC 精度
# --------------------------------------
adc_bits_list = ["2bitADC","4bitADC", "6bitADC"]  # 要绘制的 ADC 精度
adc_colors = ["blue", "red", "orange"]           # 不同 ADC 精度的颜色
adc_labels = ["Analog RNG (2bitADC)","Analog RNG (4bitADC)", "Analog RNG (6bitADC)"]

for adc_bit, color_adc, label_adc in zip(adc_bits_list, adc_colors, adc_labels):
    ps_sram_base = f"./Data/simulation/ps_sram/{adc_bit}/ARNG1"
    results_ps = []

    for mux in mux_ratios:
        mux_value = int(mux.replace("mux", ""))
        area_path = os.path.join(ps_sram_base, mux, "area", "ps_sram_area_data_128x128.json")
        latency_path = os.path.join(ps_sram_base, mux, "latency", "ps_sram_latency_data_128x128.json")

        if not (os.path.exists(area_path) and os.path.exists(latency_path)):
            continue

        with open(area_path, "r") as f:
            area_data = json.load(f)
        # 注意字段名大小写不同情况
        total_area = area_data.get("used_area", None) or area_data.get("Used_area", None)
        num_cols = area_data.get("num_cols", None)

        with open(latency_path, "r") as f:
            latency_data = json.load(f)
        total_latency = latency_data.get("Total Read Latency (s)", None)

        if total_area and total_latency and num_cols:
            bandwidth = num_cols / (mux_value * total_latency)
            results_ps.append({
                "mux": mux,
                "area": total_area,
                "bandwidth": bandwidth
            })

    if len(results_ps) > 0:
        results_ps.sort(key=lambda r: r["area"])
        areas_ps = np.array([r["area"] for r in results_ps])
        bandwidths_ps = np.array([r["bandwidth"] for r in results_ps])

        # 三阶拟合
        fit_coeffs_ps = np.polyfit(areas_ps, bandwidths_ps, deg=3)
        fit_poly_ps = np.poly1d(fit_coeffs_ps)
        x_fit_ps = np.linspace(areas_ps.min(), areas_ps.max(), 200)
        y_fit_ps = fit_poly_ps(x_fit_ps)

        # 绘制曲线 + 散点
        plt.scatter(areas_ps, bandwidths_ps, s=60, color=color_adc, marker="o")
        plt.plot(x_fit_ps, y_fit_ps, "--", color=color_adc, linewidth=2.2, label=label_adc)

# --------------------------------------
# 3️⃣ 图形美化
# --------------------------------------
plt.xlabel("Total Area (m²)")
plt.ylabel("Bandwidth (cols / (MUX × s))")
plt.title("Bandwidth vs Area for Digital CLT and Analog RNG (4bit/6bit ADC, 128×128)")
plt.legend(title="Configuration", fontsize=9)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = [130, 90, 65, 45, 32, 22]

# 对应的数据
# width = [0.00037, 0.00025, 0.00018, 0.00012, 9.13408e-05, 6.27968e-05]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
area = [2.367272182768412e-08, 1.9326465308452133e-08, 1.4628754219952013e-08, 1.040977820571037e-08, 8.01014641202208e-09, 6.280719921042295e-09]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
# plt.bar(x - bar_width, width, width=bar_width, label='Width')
# plt.bar(x, height, width=bar_width, label='Height')
plt.bar(x + bar_width, area, width=bar_width, label='Latency')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Technology Node (nm)')
plt.ylabel('Latency (s)')
plt.title('Latency across Technology Nodes')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = [130, 90, 65, 45, 32, 22]

# 对应的数据
width = [1.330e-06, 8.587e-07, 6.292e-07, 4.590e-07, 3.320e-07, 2.527e-07]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x, width, width=bar_width, label='Technology')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Technology Node (nm)')
plt.ylabel('Power (W)')
plt.title('Leakage across Technology Nodes')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = [130, 90, 65, 45, 32, 22]

# 对应的数据
width = [3.023520129607674e-11, 1.7697828814297786e-11, 1.1021457532383172e-11 , 4.1055628037626484e-12 , 3.694954923245264e-12, 1.596806617780345e-12]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x, width, width=bar_width, label='Technology')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Technology Node (nm)')
plt.ylabel('Energy (J)')
plt.title('Dynamic Energy across Technology Nodes')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = [130, 90, 65, 45, 32, 22]

# 对应的数据
width = [0.00037, 0.00025, 0.00018, 0.00012, 9.13408e-05, 6.27968e-05]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x - bar_width, width, width=bar_width, label='Width')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Technology Node (nm)')
plt.ylabel('Value')
plt.title('Width, Height, and Area across Technology Nodes')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = ['SRAM', 'RRAM']

# 对应的数据
width = [4.303e-15, 3.639e-10]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x, width, width=bar_width, label='22nm')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Memory Types')
plt.ylabel('Energy (J)')
plt.title('Dyanamic Power across Memory Types')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = ['SRAM', 'RRAM']

# 对应的数据
width = [1.208e-07, 1.334e-07]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x, width, width=bar_width, label='22nm')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Memory Types')
plt.ylabel('Power (W)')
plt.title('Leakage across Memory Types')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 工艺节点（从大到小）
technology = ['SRAM', 'RRAM']

# 对应的数据
width = [6.377387259312335e-09, 8.470308103823669e-09]
# height = [0.00036, 0.000245, 0.000170, 0.00011, 7.942538890268936e-05, 5.447016539972032e-05]
# area = [0.1338, 0.0629, 0.03155, 0.01438, 0.00725, 0.003420]

# 横坐标位置
x = np.arange(len(technology))

# 柱子宽度
bar_width = 0.25

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(x, width, width=bar_width, label='22nm')
# plt.bar(x, height, width=bar_width, label='Height')
# plt.bar(x + bar_width, area, width=bar_width, label='Area')

# 添加标签和标题
plt.xticks(x, technology)
plt.xlabel('Memory Types')
plt.ylabel('Latency (s)')
plt.title('Power across Memory Types')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 各模块名称
labels = [
    'Array',
    'WL Decoder',
    'WL Decoder Driver',
    'Level Shifter',
    'MUX',
    'ADC',
    'RNG Block'
]

# 对应面积数据
areas = [
    3.3226751999999997e-09,
    1.8413158399999993e-09,
    1.03574016e-09,
    7.664477184e-09,
    0,
    1.104789504e-08 ,
    4.051878272e-09
]

total_area = 0.06425209575713017
# 过滤掉面积为 0 的模块（例如 MUX）
filtered_labels = [label for label, area in zip(labels, areas) if area > 0]
filtered_areas = [area for area in areas if area > 0]

# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie(filtered_areas, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
plt.title('Area Breakdown (65nm RRAM)')
plt.text(1.2, 0.0, f'Total Area:\n{total_area:.4e} mm²', fontsize=12, verticalalignment='center')
plt.axis('equal')  # 让饼图看起来是圆形的
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 各模块名称
labels = [
    'Array',
    'Pre_charger',
    'sram_write_driver',
    'WL Decoder',
    'MUX',
    'Sense Amplifier',
    'ADC',
    'RNG Block'
]

# 对应面积数据
areas = [
    9.370211760000001e-09,
    8.976414719999999e-10,
    2.1865625599999998e-09,
    1.8413158399999993e-09,
    0,
    6.06879e-09,
    1.1047895039999996e-08,
    4.051878272e-09
]

total_area = 0.06690734142963199
# 过滤掉面积为 0 的模块（例如 MUX）
filtered_labels = [label for label, area in zip(labels, areas) if area > 0]
filtered_areas = [area for area in areas if area > 0]

# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie(filtered_areas, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
plt.title('Area Breakdown (65nm SRAM 2kB)')
plt.text(1.2, 0.0, f'Total Area:\n{total_area:.4e} mm²', fontsize=12, verticalalignment='center')
plt.axis('equal')  # 让饼图看起来是圆形的
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
# 各模块名称
labels = [
    'Array',
    'Pre_charger',
    'sram_write_driver',
    'WL Decoder',
    'MUX',
    'Sense Amplifier',
    'SAR ADC',
    'DFF',
    'RNG Block'
]

areas = [
    1.9382272e-08, 
    3.4524672e-10, 
    4.603289599999999e-10, 
    7.365263359999997e-09, 
    0,
    6.9049344e-10, 
    4.319522895827854e-08, 
    2.3016448e-09, 
    3.0331425279999997e-09
]


total_area = 0.06338230155367205
# 过滤掉面积为 0 的模块（例如 MUX）
filtered_labels = [label for label, area in zip(labels, areas) if area > 0]
filtered_areas = [area for area in areas if area > 0]

# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie(filtered_areas, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
plt.title('Area Breakdown (130nm SRAM)')
plt.text(1.2, 0.0, f'Total Area:\n{total_area:.4e} mm²', fontsize=12, verticalalignment='center')
plt.axis('equal')  # 让饼图看起来是圆形的
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
# 各模块名称
labels = [
    'Other',
    'wl_decoder_read_energy',
    'precharger_read_energy',
    'ADC_read_energy',
    'sense_amp_read_energy',
    'mux',
    'RNG_energy',
]

areas = [
    3.73577014465829e-12, 
    5.035361139007878e-13, 
    6.045501392490431e-12, 
    4.0693080056073594e-12, 
    1.7719949105132184e-13,
    0,
    2.06063734088921e-12, 
]


total_area = 3.736e-12
# 过滤掉面积为 0 的模块（例如 MUX）
filtered_labels = [label for label, area in zip(labels, areas) if area > 0]
filtered_areas = [area for area in areas if area > 0]

# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie(filtered_areas, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
plt.title('Energy Breakdown (65nm SRAM)')
plt.text(1.2, 1.0, f'Total Energy:\n{total_area:.4e} J', fontsize=12, verticalalignment='center')
plt.axis('equal')  # 让饼图看起来是圆形的
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
# 各模块名称
labels = [
    'Other',
    'ADC_read_energy',
    'mux_read_energy',
    'wl_decoder_read_energy',
    'wlDecoderDriver_read_energy',
    'RNG_energy',
]

areas = [
    6.174297006364775e-13, 
    7.0775139908273805e-12, 
    0, 
    5.035361139007878e-13, 
    4.620123580253959e-15,
    2.06063734088921e-12, 
]


total_area = 1.075e-11
# 过滤掉面积为 0 的模块（例如 MUX）
filtered_labels = [label for label, area in zip(labels, areas) if area > 0]
filtered_areas = [area for area in areas if area > 0]

# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie(filtered_areas, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
plt.title('Energy Breakdown (65nm RRAM 2kB)')
plt.text(1.2, 0.0, f'Total Energy:\n{total_area:.4e} J', fontsize=12, verticalalignment='center')
plt.axis('equal')  # 让饼图看起来是圆形的
plt.tight_layout()
plt.show()

# %%
import pandas as pd
filename = './Data/currents_vlsi.csv'
# filename = './Data/customized_gaussian_current.csv'

df = pd.read_csv(filename, header=None)
customized_gaussian_current = df.to_numpy()
#normalize to standard normal distribution
customized_gaussian_current = (customized_gaussian_current - np.mean(customized_gaussian_current)) / np.std(customized_gaussian_current)

# histogram = plt.hist(customized_gaussian_current, bins=20)
print("maen: ", np.mean(customized_gaussian_current))
print("std: ", np.std(customized_gaussian_current))
customized_gaussian_current = customized_gaussian_current.flatten()
print("dimension of customized_gaussian_current: ", customized_gaussian_current.shape)
# Out:
# maen:  -3.1619151741324457e-16
# std:  1.0
# dimension of customized_gaussian_current:  (1000,)

# %%
import numpy as np
from scipy.stats import norm, skew, kurtosis, kstest, wasserstein_distance
import matplotlib.pyplot as plt

# ====== 参数设置 ======
num_samples = 1000      # 样本数量
num_uniforms = 8        # 叠加多少个均匀分布 (CLT参数)
quantization_bits = 16    # 模拟LFSR输出位宽（量化精度）

# ====== 生成原始均匀随机数 ======
uniforms = np.random.rand(num_uniforms, num_samples)

# ====== 模拟 LFSR 量化过程 ======
levels = 2 ** quantization_bits
uniforms_q = np.floor(uniforms * levels) / levels  # 均匀量化到 [0, 1)
print(f"Quantization bits: {quantization_bits}, Levels: {levels}")
print(f"Uniform sample range after quantization: [{np.min(uniforms_q):.4f}, {np.max(uniforms_q):.4f}]")

# ====== CLT 叠加生成伪高斯随机数 ======
clt_data = np.sum(uniforms_q, axis=0) - num_uniforms / 2  # 均值居中
clt_data = (clt_data - np.mean(clt_data)) / np.std(clt_data)  # 标准化为N(0,1)
print("CLT data dimension:", clt_data.shape)

# ====== 生成理想高斯随机数 ======
ideal_data = np.random.normal(0, 1, num_samples)


print("dimension of clt_data: ", clt_data.shape)
# Out:
# Quantization bits: 8, Levels: 256
# Uniform sample range after quantization: [0.0000, 0.9961]
# CLT data dimension: (1000,)
# dimension of clt_data:  (1000,)

# %%
# ====== 基本统计指标 ======
mean_val = np.mean(clt_data)
std_val = np.std(clt_data)
skew_val = skew(clt_data)
kurt_val = kurtosis(clt_data, fisher=False)

# ====== 拟合优度检验 ======
ks_stat, ks_p = kstest(clt_data, 'norm')
chi_hist, bin_edges = np.histogram(clt_data, bins=50)
expected = len(clt_data) * np.diff(norm.cdf(bin_edges))
expected *= chi_hist.sum() / expected.sum()
chi_stat, chi_p = chisquare(chi_hist, expected)

# ====== Wasserstein 距离 ======
wasserstein_dist = wasserstein_distance(clt_data, ideal_data)

# ====== Print results (with reference indicators) ======
print("=== CLT Gaussian Random Number Quality Analysis ===")
print(f"Samples: {num_samples}, Uniform distributions summed: {num_uniforms}")
print("-" * 70)
print(f"{'Metric':<25}{'Result':>15}{'Ideal Gaussian Reference':>30}")
print("-" * 70)
print(f"{'Mean':<25}{mean_val:>15.5f}{'≈ 0':>30}")
print(f"{'Standard Deviation':<25}{std_val:>15.5f}{'≈ 1':>30}")
print(f"{'Skewness':<25}{skew_val:>15.5f}{'≈ 0 (Symmetric)':>30}")
print(f"{'Kurtosis':<25}{kurt_val:>15.5f}{'≈ 3 (Tail thickness)':>30}")
print(f"{'K–S Test p-value':<25}{ks_p:>15.5f}{'> 0.05 → Good fit':>30}")
print(f"{'Chi-square Test p-value':<25}{chi_p:>15.5f}{'> 0.05 → No significant diff.':>30}")
print(f"{'Wasserstein Distance':<25}{wasserstein_dist:>15.5f}{'< 0.05 → Close to ideal Gaussian':>30}")
print("-" * 70)

# ====== 绘制可视化 ======
plt.figure()
plt.title("CLT vs Ideal Gaussian (PDF)")
plt.hist(clt_data, bins=80, density=True, histtype='step', label='CLT-generated')
x = np.linspace(-4, 4, 200)
plt.plot(x, norm.pdf(x), label='Ideal Gaussian')
plt.legend()
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid()

plt.figure()
plt.title("QQ Plot (CLT vs Ideal Gaussian)")
theoretical_quantiles = np.quantile(ideal_data, np.linspace(0, 1, num_samples))
sample_quantiles = np.quantile(clt_data, np.linspace(0, 1, num_samples))
plt.scatter(theoretical_quantiles[::500], sample_quantiles[::500], s=5, label="Quantiles")
plt.plot([-4, 4], [-4, 4], 'r--', label="y=x")
plt.legend()
plt.xlabel("Ideal quantiles")
plt.ylabel("CLT quantiles")
plt.grid()

plt.show()
# Out:
# === CLT Gaussian Random Number Quality Analysis ===
# Samples: 1000, Uniform distributions summed: 8
# ----------------------------------------------------------------------
# Metric                            Result      Ideal Gaussian Reference
# ----------------------------------------------------------------------
# Mean                            -0.00000                           ≈ 0
# Standard Deviation               1.00000                           ≈ 1
# Skewness                         0.01811               ≈ 0 (Symmetric)
# Kurtosis                         2.89577          ≈ 3 (Tail thickness)
# K–S Test p-value                 0.96632             > 0.05 → Good fit
# Chi-square Test p-value          0.69185 > 0.05 → No significant diff.
# Wasserstein Distance             0.05371< 0.05 → Close to ideal Gaussian
# ----------------------------------------------------------------------

# %% [markdown]
# === CLT Gaussian Random Number Quality Analysis ===
# Samples: 1000, Uniform distributions summed: 3
# ----------------------------------------------------------------------
# Metric                            Result      Ideal Gaussian Reference
# ----------------------------------------------------------------------
# Mean                             0.00000                           ≈ 0
# Standard Deviation               1.00000                           ≈ 1
# Skewness                         0.11856               ≈ 0 (Symmetric)
# Kurtosis                         2.49870          ≈ 3 (Tail thickness)
# K–S Test p-value                 0.11941             > 0.05 → Good fit
# Chi-square Test p-value          0.07034 > 0.05 → No significant diff.
# Wasserstein Distance             0.07310< 0.05 → Close to ideal Gaussian
# ----------------------------------------------------------------------
#
#
# === CLT Gaussian Random Number Quality Analysis ===
# Samples: 1000, Uniform distributions summed: 15
# ----------------------------------------------------------------------
# Metric                            Result      Ideal Gaussian Reference
# ----------------------------------------------------------------------
# Mean                             0.00000                           ≈ 0
# Standard Deviation               1.00000                           ≈ 1
# Skewness                         0.03293               ≈ 0 (Symmetric)
# Kurtosis                         2.81720          ≈ 3 (Tail thickness)
# K–S Test p-value                 0.89374             > 0.05 → Good fit
# Chi-square Test p-value          0.47379 > 0.05 → No significant diff.
# Wasserstein Distance             0.04773< 0.05 → Close to ideal Gaussian
# ----------------------------------------------------------------------

# %%
# ====== 基本统计指标 ======
mean_val = np.mean(customized_gaussian_current)
std_val = np.std(customized_gaussian_current)
skew_val = skew(customized_gaussian_current)
kurt_val = kurtosis(customized_gaussian_current, fisher=False)

# ====== 拟合优度检验 ======
ks_stat, ks_p = kstest(customized_gaussian_current, 'norm')
chi_hist, bin_edges = np.histogram(customized_gaussian_current, bins=50)
expected = len(customized_gaussian_current) * np.diff(norm.cdf(bin_edges))
expected *= chi_hist.sum() / expected.sum()
chi_stat, chi_p = chisquare(chi_hist, expected)

# ====== Wasserstein 距离 ======
wasserstein_dist = wasserstein_distance(customized_gaussian_current, ideal_data)

# ====== Print results (with reference indicators) ======
print("=== Analog Gaussian Random Number Quality Analysis ===")
print("-" * 70)
print(f"{'Metric':<25}{'Result':>15}{'Ideal Gaussian Reference':>30}")
print("-" * 70)
print(f"{'Mean':<25}{mean_val:>15.5f}{'≈ 0':>30}")
print(f"{'Standard Deviation':<25}{std_val:>15.5f}{'≈ 1':>30}")
print(f"{'Skewness':<25}{skew_val:>15.5f}{'≈ 0 (Symmetric)':>30}")
print(f"{'Kurtosis':<25}{kurt_val:>15.5f}{'≈ 3 (Tail thickness)':>30}")
print(f"{'K–S Test p-value':<25}{ks_p:>15.5f}{'> 0.05 → Good fit':>30}")
print(f"{'Chi-square Test p-value':<25}{chi_p:>15.5f}{'> 0.05 → No significant diff.':>30}")
print(f"{'Wasserstein Distance':<25}{wasserstein_dist:>15.5f}{'< 0.05 → Close to ideal Gaussian':>30}")
print("-" * 70)

# ====== 绘制可视化 ======
plt.figure()
plt.title("CLT vs Ideal Gaussian (PDF)")
plt.hist(clt_data, bins=80, density=True, histtype='step', label='CLT-generated')
x = np.linspace(-4, 4, 200)
plt.plot(x, norm.pdf(x), label='Ideal Gaussian')
plt.legend()
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid()

plt.figure()
plt.title("QQ Plot (CLT vs Ideal Gaussian)")
theoretical_quantiles = np.quantile(ideal_data, np.linspace(0, 1, num_samples))
sample_quantiles = np.quantile(clt_data, np.linspace(0, 1, num_samples))
plt.scatter(theoretical_quantiles[::500], sample_quantiles[::500], s=5, label="Quantiles")
plt.plot([-4, 4], [-4, 4], 'r--', label="y=x")
plt.legend()
plt.xlabel("Ideal quantiles")
plt.ylabel("CLT quantiles")
plt.grid()

plt.show()
# Out:
# === Analog Gaussian Random Number Quality Analysis ===
# ----------------------------------------------------------------------
# Metric                            Result      Ideal Gaussian Reference
# ----------------------------------------------------------------------
# Mean                            -0.00000                           ≈ 0
# Standard Deviation               1.00000                           ≈ 1
# Skewness                         0.09916               ≈ 0 (Symmetric)
# Kurtosis                         2.75994          ≈ 3 (Tail thickness)
# K–S Test p-value                 0.67710             > 0.05 → Good fit
# Chi-square Test p-value          0.16974 > 0.05 → No significant diff.
# Wasserstein Distance             0.06750< 0.05 → Close to ideal Gaussian
# ----------------------------------------------------------------------

# %%
import numpy as np
from scipy.stats import norm, skew, kurtosis, kstest, wasserstein_distance, chisquare
import matplotlib.pyplot as plt

# ===== 参数设置 =====
num_samples = 100000
quantization_bits = 16
uniform_counts = [2, 4, 6, 8, 10, 12, 14, 16]

# ===== 存储结果 =====
metrics = {
    "Mean": [],
    "Std": [],
    "Skewness": [],
    "Kurtosis": [],
    "KS_p": [],
    "Wasserstein": []
}

# ===== 扫描不同的 num_uniforms =====
for num_uniforms in uniform_counts:
    # --- 生成均匀随机数 ---
    uniforms = np.random.rand(num_uniforms, num_samples)

    # --- 模拟量化（模拟LFSR输出） ---
    levels = 2 ** quantization_bits
    uniforms_q = np.floor(uniforms * levels) / levels

    # --- CLT 叠加 ---
    clt_data = np.sum(uniforms_q, axis=0) - num_uniforms / 2
    clt_data = (clt_data - np.mean(clt_data)) / np.std(clt_data)

    # --- 理想高斯样本 ---
    ideal_data = np.random.normal(0, 1, num_samples)

    # --- 计算指标 ---
    mean_val = np.mean(clt_data)
    std_val = np.std(clt_data)
    skew_val = skew(clt_data)
    kurt_val = kurtosis(clt_data, fisher=False)
    ks_stat, ks_p = kstest(clt_data, 'norm')
    wasserstein_dist = wasserstein_distance(clt_data, ideal_data)

    # --- 保存结果 ---
    metrics["Mean"].append(mean_val)
    metrics["Std"].append(std_val)
    metrics["Skewness"].append(skew_val)
    metrics["Kurtosis"].append(kurt_val)
    metrics["KS_p"].append(ks_p)
    metrics["Wasserstein"].append(wasserstein_dist)

    print(f"[CLT{num_uniforms}] Done: Wasserstein = {wasserstein_dist:.4f}, KS_p = {ks_p:.4f}")

# ===== 绘图部分 =====
plt.figure(figsize=(10, 6))
plt.plot(uniform_counts, metrics["Wasserstein"], marker='o', linewidth=2, label='Wasserstein Distance')
# plt.plot(uniform_counts, metrics["KS_p"], marker='s', linewidth=2, label='K–S Test p-value')
plt.xlabel('Number of Uniform Distributions (CLT count)', fontsize=12)
plt.ylabel('Metric Value', fontsize=12)
plt.title('CLT Convergence Metrics vs Number of Summed Uniform Distributions', fontsize=13)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# ===== 可选：画出形状指标 (Skewness, Kurtosis) =====
plt.figure(figsize=(10, 6))
plt.plot(uniform_counts, metrics["Skewness"], marker='o', linewidth=2, label='Skewness')
plt.plot(uniform_counts, metrics["Kurtosis"], marker='s', linewidth=2, label='Kurtosis')
plt.axhline(0, color='gray', linestyle='--', alpha=0.5)
plt.axhline(3, color='gray', linestyle='--', alpha=0.5)
plt.xlabel('Number of Uniform Distributions (CLT count)', fontsize=12)
plt.ylabel('Shape Metrics', fontsize=12)
plt.title('CLT Gaussian Shape Metrics vs Number of Summed Uniform Distributions', fontsize=13)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# [CLT2] Done: Wasserstein = 0.0468, KS_p = 0.0000
# [CLT4] Done: Wasserstein = 0.0211, KS_p = 0.0000
# [CLT6] Done: Wasserstein = 0.0158, KS_p = 0.0012
# [CLT8] Done: Wasserstein = 0.0122, KS_p = 0.0033
# [CLT10] Done: Wasserstein = 0.0084, KS_p = 0.2228
# [CLT12] Done: Wasserstein = 0.0069, KS_p = 0.1829
# [CLT14] Done: Wasserstein = 0.0065, KS_p = 0.1669
# [CLT16] Done: Wasserstein = 0.0037, KS_p = 0.3346

# %%
import matplotlib.pyplot as plt
import numpy as np

# 不同 CLT 叠加数量（单位：kB）
memory_sizes = ['CLT4', 'CLT6', 'CLT8', 'CLT10', 'CLT12', 'CLT14', 'CLT16']

# 对应的 Memory Density（bit/mm²）
bits_per_mm2_sram = [2090.879954, 2657.159938, 3213.359921, 3783.959905, 
                     4342.679888, 4908.959871, 5461.919853]

# 数值索引
x = np.arange(len(memory_sizes))

# 绘制折线图
plt.figure(figsize=(8, 5))
plt.plot(x, bits_per_mm2_sram, marker='o', linewidth=2, markersize=8)

# 设置坐标轴标签与标题
plt.xticks(x, memory_sizes)
plt.xlabel('Number of CLT Accumulations', fontsize=12)
plt.ylabel('Memory (um²)', fontsize=12)
plt.title('Area VS CLT Accumulation Count', fontsize=13)

# 网格与样式
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 不同 CLT 叠加数量（单位：kB）
memory_sizes = ['CLT4', 'CLT6', 'CLT8', 'CLT10', 'CLT12', 'CLT14', 'CLT16']

# 对应的 Memory Density（bit/mm²）
bits_per_mm2_sram = [140.9678, 190.4046, 179.6840, 228.2045, 
                     248.7693, 271.5370, 258.4441]

# 数值索引
x = np.arange(len(memory_sizes))

# 绘制折线图
plt.figure(figsize=(8, 5))
plt.plot(x, bits_per_mm2_sram, marker='o', linewidth=2, markersize=8)

# 设置坐标轴标签与标题
plt.xticks(x, memory_sizes)
plt.xlabel('Number of CLT Accumulations', fontsize=12)
plt.ylabel('Dynamic Power (uw)', fontsize=12)
plt.title('Dynamic Power VS CLT Accumulation Count', fontsize=13)

# 网格与样式
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 不同 CLT 叠加数量（单位：kB）
memory_sizes = ['CLT4', 'CLT6', 'CLT8', 'CLT10', 'CLT12', 'CLT14', 'CLT16']

# 对应的 Memory Density（bit/mm²）
bits_per_mm2_sram = [1.1485e+03, 1.3616e+03, 1.5706e+03, 1.7883e+03, 
                     1.9971e+03, 2.2119e+03, 2.4200e+03]

# 数值索引
x = np.arange(len(memory_sizes))

# 绘制折线图
plt.figure(figsize=(8, 5))
plt.plot(x, bits_per_mm2_sram, marker='o', linewidth=2, markersize=8)

# 设置坐标轴标签与标题
plt.xticks(x, memory_sizes)
plt.xlabel('Number of CLT Accumulations', fontsize=12)
plt.ylabel('Leakage (nw)', fontsize=12)
plt.title('Leakage VS CLT Accumulation Count', fontsize=13)

# 网格与样式
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# 显示图形
plt.show()

# %%
array_area 3.734731e-08
WL_decoder_area 3.797713919999999e-09
pre_charge_area 1.7952829439999999e-09
sram_write_driver_area 4.3731251199999995e-09
sense_amp_area 1.2125749999999999e-08
SarADC_area 6.28303321013804e-08
MultilevelSenseAmp_area 2.209579008e-08
RNG_bloclk_area 8.103756544e-09
MUX_bus_area 4.83345408e-09
MUX_area 0
muxdecoder_area 0
Area Result: 0.2013528103182603
memory density: 325478.4469926848


array_area 3.734731e-08
WL_decoder_area 3.797713919999999e-09
pre_charge_area 1.7952829439999999e-09
sram_write_driver_area 4.3731251199999995e-09
sense_amp_area 1.2125749999999999e-08
SarADC_area 6.28303321013804e-08
MultilevelSenseAmp_area 2.209579008e-08
RNG_bloclk_area 8.103756544e-09
MUX_bus_area 4.83345408e-09
MUX_area 0
muxdecoder_area 0
Area Result: 0.105273688884
memory density: 622529.7193889866

# %% [markdown]
# array_area 3.734731e-08
# array_height 0.00010010000000000001
# array_width 0.0003731
# WL_decoder_area 3.797713919999999e-09
# pre_charge_area 1.7952829439999999e-09
# pre_charge_height 2.366e-06
# pre_charge_width 0.000758784
# sram_write_driver_area 4.3731251199999995e-09
# sram_write_driver_height 6.9159999999999995e-06
# sram_write_driver_width 0.00063232
# sense_amp_area 1.2125749999999999e-08
# sense_amp_height 1.457421875e-05
# sense_amp_width 6.5e-06
# SarADC_area 6.28303321013804e-08
# MultilevelSenseAmp_area 2.209579008e-08
# RNG_bloclk_area 8.103756544e-09
# MUX_bus_area 4.83345408e-09
# MUX_area 0
# muxdecoder_area 0
# Width Result: 0.0008369919999999999
# Height Result: 0.0002405671862075866
# Area Result: 0.2013528103182603
# Used Area Result: 0.094472182688
# memory density: 325478.4469926848

# %%
array_area_unit = 3.734731e-08/256/256
adc_area_unit = 6.28303321013804e-08/256
ratio = adc_area_unit / array_area_unit
print("array_area_unit =", array_area_unit)
print("adc_area_unit =", adc_area_unit)
print("ratio =", ratio)
# Out:
# array_area_unit = 5.698747253417969e-13
# adc_area_unit = 2.4543098477101717e-10
# ratio = 430.6753289046354

# %%
density_256_256_ps = 325478.4469926848
density_256_256_sram = 622529.7193889866
array_area = 1.4912244984e-07
area_256_256 = 0.6427054608010558 *1e-06
area_other = area_256_256 - array_area
memory_ratio = array_area/area_256_256
print("memory ratio: ", memory_ratio)
print("area other: ", area_other)
print("array area: ", array_area)
print("area 256 256: ", area_256_256)


density_ratio = density_256_256_ps / density_256_256_sram
print("density ratio: ", density_ratio)

density_512_512_ps = 407875.7937940479
density_512_512_sram = 694115.8925821437
array_area = 1.4912244984e-07
area_512_512 = 0.6427054608010558e-6
area_other = area_512_512 - array_area
memory_ratio = array_area/area_512_512
print("memory ratio 512: ", memory_ratio)
print("area other 512: ", area_other)
print("array area 512: ", array_area)
print("area 512 512: ", area_512_512)
density_ratio_512 = density_512_512_ps / density_512_512_sram
print("density ratio 512: ", density_ratio_512)

array_area = 5.9595650296e-07
area_1024_1024 = 2.1600603732540824e-06
area_other = area_1024_1024 - array_area
memory_ratio = array_area/area_1024_1024
print("memory ratio 1024: ", memory_ratio)
print("area other 1024: ", area_other)
print("array area 1024: ", array_area)
print("area 1024 1024: ", area_1024_1024)
# Out:
# memory ratio:  0.23202300110245933
# area other:  4.935830109610558e-07
# array area:  1.4912244984e-07
# area 256 256:  6.427054608010558e-07
# density ratio:  0.522831981920706
# memory ratio 512:  0.23202300110245933
# area other 512:  4.935830109610558e-07
# array area 512:  1.4912244984e-07
# area 512 512:  6.427054608010558e-07
# density ratio 512:  0.5876191543125902
# memory ratio 1024:  0.2758980768959735
# area other 1024:  1.5641038702940825e-06
# array area 1024:  5.9595650296e-07
# area 1024 1024:  2.1600603732540824e-06
